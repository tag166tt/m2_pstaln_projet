# %%
import collections
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torchcrf import CRF
from sklearn import preprocessing

import collections
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pickle


def train_test_split_sentences(X, y, test_size=0.3, random_state=0, shuffle=True) :
    X_by_sentences = []
    y_by_sentences = []
    sentence = []
    sentence_tags = []
    for line, tag in zip(X, y):
        if line == '':
            if len(sentence) != 0:
                sentence.append([sentence[-1][0]+1, '<eos>', '', ''])
                sentence_tags.append('<eos>')
                X_by_sentences.append(sentence)
                y_by_sentences.append(sentence_tags)
                sentence = []
                sentence_tags = []
        else:
            sentence.append(line)
            sentence_tags.append(tag)

    X, X_val, y, y_val = train_test_split(X_by_sentences, y_by_sentences, test_size=test_size, random_state=random_state, shuffle=shuffle)

    X = [y for x in X for y in x]
    X_val = [y for x in X_val for y in x]
    y = [y_1 for x in y for y_1 in x]
    y_val = [y for x in y_val for y in x]

    return X, X_val, y, y_val


def write_data(X_test, y_test, filename):
    #xi_test format: num, word, lem, POS
    with open(filename, 'w', encoding='utf-8') as f:
        is_first = True
        for xi_test, yi_test in zip(X_test, y_test):
            if (xi_test[1] == '<eos>'):# or (yi_test == '<eos>'):
                continue
            if (not is_first) and xi_test[0] == 1:
                f.write('\n')
            yi_test = yi_test if yi_test != '<eos>' else ''
            f.write(f'{xi_test[0]}\t{xi_test[1]}\t-\t{xi_test[3]}\tO\t0\t\t{yi_test}\n')
            is_first = False
        f.write('\n')


def extract_data(data_in):
    X, y = [], []
    for i, line in enumerate(data_in):
        if line != '\n':
            num, word, lem, pos, mwe, _, _, supersenses, _ = line[:-1].split('\t')
            X.append([int(num), word, lem, pos])
            y.append(supersenses)
        else :
            X.append('')
            y.append('')
    return X, y

"""
def transform(X, y, X_val, y_val, max_len=16, batch_size=64):
    #le = preprocessing.LabelEncoder()
    #le.fit(y+y_val)#+["<eos>"])
    #int_labels = le.transform(y)
    #int_labels_val = le.transform(y_val)
    le = collections.defaultdict(lambda: len(le))
    le['<eos>'] = 0
    int_labels = [le[yi] for yi in y]
    int_labels_val = [le[yi] for yi in y_val]
    
    #le_vocab = preprocessing.LabelEncoder()
    #vocab = [text for _, text, _, _ in X]#+["<eos>"]
    #vocab_val = [text for _, text, _, _ in X_val]#+["<eos>"]
    ##int_texts = le_vocab.fit_transform(vocab)
    ##int_texts_val = le_vocab.fit_transform(vocab_val)
    #le_vocab.fit(vocab+vocab_val)
    #int_texts = le_vocab.transform(vocab)
    #int_texts_val = le_vocab.transform(vocab_val)
    le_vocab = collections.defaultdict(lambda: len(le_vocab))
    le_vocab['<eos>'] = 0
    vocab = [text for _, text, _, _ in X]
    vocab_val = [text for _, text, _, _ in X_val]
    int_texts = [le_vocab[word] for word in vocab]
    int_texts_val = [le_vocab[word] for word in vocab_val]
    
    def encode_sentence(int_texts, int_labels):
        temp_x, temp_y, final_y, final_x = [], [], [], []
        #eos_symbol = le_vocab.transform(['<eos>'])
        eos_symbol = le_vocab['<eos>']
        for x, y in zip(int_texts, int_labels) :
            temp_x.append(x)
            temp_y.append(y)
            if x == eos_symbol :
                final_x.append(temp_x)
                final_y.append(temp_y)
                temp_x = []
                temp_y = []
        
        X = torch.zeros(len(final_x), max_len).long()
        Y = torch.zeros(len(final_y), max_len).long()
        for i, (text, label) in enumerate(zip(final_x, final_y)):
            length = min(max_len, len(text))
            X[i,:length] = torch.LongTensor(text[:length])
            Y[i,:length] = torch.LongTensor(label[:length])
        
        print(len(int_texts))
        print(len(final_x))
        print(X.size())
        
        return X, Y

    #print(len(int_texts))
    #print(len(int_texts_val))
    
    X_train, Y_train = encode_sentence(int_texts, int_labels)
    X_valid, Y_valid = encode_sentence(int_texts_val, int_labels_val)
    
    #print(X_valid.size())
    #print(X_train.size())
    
    train_set = TensorDataset(X_train, Y_train)
    valid_set = TensorDataset(X_valid, Y_valid)

    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_set, batch_size=batch_size)
    
    return vocab, le_vocab, le, train_loader, valid_loader
"""

le_pos = collections.defaultdict(lambda: len(le_pos))
def transform(X, y, X_val, y_val, max_len=16, batch_size=64):
    #le = preprocessing.LabelEncoder()
    #le.fit(y+y_val)#+["<eos>"])
    #int_labels = le.transform(y)
    #int_labels_val = le.transform(y_val)
    le = collections.defaultdict(lambda: len(le))
    le['<eos>'] = 0
    int_labels = [le[yi] for yi in y]
    int_labels_val = [le[yi] for yi in y_val]
    
    #le_vocab = preprocessing.LabelEncoder()
    #vocab = [text for _, text, _, _ in X]#+["<eos>"]
    #vocab_val = [text for _, text, _, _ in X_val]#+["<eos>"]
    ##int_texts = le_vocab.fit_transform(vocab)
    ##int_texts_val = le_vocab.fit_transform(vocab_val)
    #le_vocab.fit(vocab+vocab_val)
    #int_texts = le_vocab.transform(vocab)
    #int_texts_val = le_vocab.transform(vocab_val)
    le_vocab = collections.defaultdict(lambda: len(le_vocab))
    le_vocab['<eos>'] = 0
    #vocab = [text for _, text, _, pos in X]
    vocab = [[text, pos] for _, text, _, pos in X]
    #vocab_val = [text for _, text, _, pos in X_val]
    vocab_val = [[text, pos] for _, text, _, pos in X_val]
    int_texts = [[le_vocab[word], le_pos[pos]] for word, pos in vocab]
    int_texts_val = [[le_vocab[word], le_pos[pos]] for word, pos in vocab_val]
    
    def encode_sentence(int_texts, int_labels):
        temp_x, temp_y, final_y, final_x = [], [], [], []
        #eos_symbol = le_vocab.transform(['<eos>'])
        eos_symbol = le_vocab['<eos>']
        for x, y in zip(int_texts, int_labels) :
            temp_x.append(x)
            temp_y.append(y)
            if x[0] == eos_symbol :
                final_x.append(temp_x)
                final_y.append(temp_y)
                temp_x = []
                temp_y = []
        
        X = torch.zeros(len(final_x), max_len, 2).long()
        Y = torch.zeros(len(final_y), max_len).long()
        for i, (text, label) in enumerate(zip(final_x, final_y)):
            length = min(max_len, len(text))
            X[i,:length] = torch.LongTensor(text[:length])
            Y[i,:length] = torch.LongTensor(label[:length])
        
        print(len(int_texts))
        print(len(final_x))
        print(X.size())
        
        return X, Y

    #print(len(int_texts))
    #print(len(int_texts_val))
    
    X_train, Y_train = encode_sentence(int_texts, int_labels)
    X_valid, Y_valid = encode_sentence(int_texts_val, int_labels_val)
    
    #print(X_valid.size())
    #print(X_train.size())
    
    train_set = TensorDataset(X_train, Y_train)
    valid_set = TensorDataset(X_valid, Y_valid)

    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_set, batch_size=batch_size)
    
    return vocab, le_vocab, le, train_loader, valid_loader


def load_pretrained_weights(filename, vocab_size=None, le_vocab=None, from_pickle=False, dim=300):
    """
    from_pickle: 'pretrained_weights.pkl'
    from_vec: 'wiki-news-300d-1M.vec'
    """
    if from_pickle:
        with open(filename, 'rb') as fin:
            pretrained_weights = pickle.load(fin)
    else: # from_vec
        pretrained_weights = torch.zeros(vocab_size, dim)
        with open(filename, encoding="utf-8") as fp:
            fp.readline()
            for line in fp:
                tokens = line.strip().split()
                #if tokens[0].lower() in le_vocab.classes_:
                if tokens[0].lower() in le_vocab:
                    pretrained_weights[le_vocab[tokens[0].lower()]] = torch.FloatTensor([float(x) for x in tokens[1:]])
                    #pretrained_weights[le_vocab.transform([tokens[0].lower()])] = torch.FloatTensor([float(x) for x in tokens[1:]])
    return pretrained_weights

# %%
from Model import Model

class GRU(nn.Module):
    def __init__(self, pretrained_weights, le, embed_size=300, hidden_size=128):
        super().__init__()
        #self.embed = nn.Embedding(len(le.classes_), embed_size, padding_idx=le.transform(['<eos>'])[0])
        self.embed = nn.Embedding(len(le), embed_size, padding_idx=le['<eos>'])
        self.embed.weight = nn.Parameter(pretrained_weights, requires_grad=False)
        self.rnn = nn.GRU(embed_size, hidden_size, bias=False, num_layers=1, bidirectional=False, batch_first=True)
        self.dropout = nn.Dropout(0.3)
        #self.decision = nn.Linear(hidden_size * 1 * 1, len(le.classes_))
        self.decision = nn.Linear(hidden_size * 1 * 1, len(le))

    def forward(self, x):
        embed = self.embed(x)
        output, hidden = self.rnn(embed)
        return self.decision(self.dropout(output))

class GRU_with_POS(nn.Module):
    def __init__(self, pretrained_weights, le, embed_size=300, hidden_size=128):
        super().__init__()
        #self.embed = nn.Embedding(len(le.classes_), embed_size, padding_idx=le.transform(['<eos>'])[0])
        self.embed = nn.Embedding(len(le), embed_size, padding_idx=le['<eos>'])
        self.embed.weight = nn.Parameter(pretrained_weights, requires_grad=False)
        self.rnn = nn.GRU(embed_size+1, hidden_size, bias=False, num_layers=1, bidirectional=False, batch_first=True)
        self.dropout = nn.Dropout(0.3)
        #self.decision = nn.Linear(hidden_size * 1 * 1, len(le.classes_))
        self.decision = nn.Linear(hidden_size * 1 * 1, len(le))

    def forward(self, x):
        embed = self.embed(x[:, :, 0])
        #print(embed.size())
        #print(x[:, :, 1].view(x.size(0), x.size(1), 1).size())
        #print(torch.cat((x[:, :, 1].view(x.size(0), x.size(1), 1), embed), dim=2).size())
        concat = torch.cat((x[:, :, 1].view(x.size(0), x.size(1), 1), embed), dim=2)
        output, hidden = self.rnn(concat)
        return self.decision(self.dropout(output))


class NN_Model(Model): # Compatible with torch model only
    def __init__(self, model, criterion=nn.CrossEntropyLoss(), optim=optim.Adam):
        super().__init__()
        self.model = model
        self.criterion = criterion
        self.optim = optim

    def fit(self, train_loader, valid_loader, epochs):
        optimizer = self.optim(filter(lambda param: param.requires_grad, self.model.parameters()))
        for epoch in range(epochs):
            self.model.train()
            total_loss = num = 0
            for x, y in train_loader:
                optimizer.zero_grad()
                y_scores = self.model(x)
                loss = self.criterion(y_scores.view(y.size(0) * y.size(1), -1), y.view(y.size(0) * y.size(1)))
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
                num += len(y)
            print(epoch+1, total_loss / num, *self.perf(valid_loader))
    
    def perf(self, loader):
        self.model.eval()
        total_loss = correct = num_loss = num_perf = 0
        for x, y in loader:
            with torch.no_grad():
                y_scores = self.model(x)
                loss = self.criterion(y_scores.view(y.size(0) * y.size(1), -1), y.view(y.size(0) * y.size(1)))
                y_pred = torch.max(y_scores, 2)[1]
                mask = (y != 0)
                correct += torch.sum((y_pred.data == y) * mask)
                total_loss += loss.item()
                num_loss += len(y)
                num_perf += torch.sum(mask).item()
        return total_loss / num_loss, correct.item() / num_perf

    def predict(self, X_test):
        self.model.eval()
        return torch.max(self.model(X_test), 2)[1]

    def score(self, X_test, y_test, exception_class): # TODO
        #return super().score(X_test, y_test, exception_class)
        """
        Returns:
            precision = #(correct)/#(predicted)
            recall = #(correct)/#(gold)
            F1_score = 2*precision*recall / (precision + recall)
            accuracy = #(correct: supersense or no-supersense)/#(tokens)
        """

        y_hat = self.predict(X_test)
        
        y_test = y_test.view((-1,))
        y_hat = y_hat.view((-1,))
        print(len(y_test))

        nb_predicted, nb_gold, nb_tokens = 0, 0, len(y_test)
        nb_correct, accuracy = 0, 0
        for yi_hat, yi in zip(y_hat, y_test):
            if yi_hat == yi:
                accuracy += 1
            if yi_hat != exception_class:
                nb_predicted += 1
            if yi != exception_class:
                nb_gold += 1
            if (yi != exception_class) and (yi == yi_hat):
                nb_correct += 1

        precision = nb_correct/nb_predicted if nb_predicted != 0 else 0.
        recall = nb_correct/nb_gold if nb_gold != 0 else 0.
        f1_score = 2*precision*recall / (precision + recall) if (precision + recall) != 0 else 0.
        accuracy = accuracy/nb_tokens
        return precision, recall, f1_score, accuracy

# %%
data = open('../dimsum-data-1.5/dimsum16.train', 'r').readlines()
data_test = open('../dimsum-data-1.5/dimsum16.test.blind', 'r', encoding='utf-8').readlines()

X, y = extract_data(data)
X, X_val, y, y_val = train_test_split_sentences(X, y)
write_data(X_val, y_val, 'val.gold')

# %%
vocab, le_vocab, le, train_loader, valid_loader = transform(X, y, X_val, y_val, max_len=16, batch_size=64)
# Out:
# 55050
# 3359
# torch.Size([3359, 16, 2])
# 23575
# 1440
# torch.Size([1440, 16, 2])

# %%
import pickle

#pretrained_weights = load_pretrained_weights('wiki-news-300d-1M.vec', vocab_size=len(vocab), le_vocab=le_vocab)
#with open(f"pretrained_weights_2.pkl", 'wb') as fo:
#    pickle.dump(pretrained_weights, fo)

pretrained_weights = load_pretrained_weights('pretrained_weights_2.pkl', from_pickle=True)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

gru_model = NN_Model(model=GRU_with_POS(pretrained_weights, le_vocab, embed_size=300, hidden_size=128),
                     criterion=nn.CrossEntropyLoss(),
                     optim=optim.Adam
                    )

gru_model.fit(train_loader, valid_loader, epochs=25)
# Out:
# 1 0.07108283731404356 0.031353670441442064 0.6704186766720267
# 2 0.028384675969677194 0.024640491273668078 0.6636293252337562
# 3 0.023536625026272465 0.021717457721630733 0.6658328866654756
# 4 0.021074600573202158 0.019613308128383425 0.6721457923887797
# 5 0.019119259004402672 0.017932635959651735 0.6735751295336787
# 6 0.017760595472556703 0.016742323463161787 0.6756595795366566
# 7 0.016750457972492198 0.01588693434993426 0.6773866952534096
# 8 0.01593866599177491 0.015167261246177885 0.6886427252694896
# 9 0.015287824154751896 0.014554420196347766 0.6991840867131202
# 10 0.014800362925545095 0.01403190435634719 0.7028169852897386
# 11 0.01430757218224905 0.013589147478342056 0.7109761181585373
# 12 0.0139155463648538 0.013227879794107543 0.7181823595974034
# 13 0.013579118443443932 0.012910589368806945 0.7286641653266631
# 14 0.013274554874116943 0.012686140131619242 0.7348579596212257
# 15 0.013053311393813882 0.012373704090714454 0.7412899767732714
# 16 0.012773082099453471 0.012144850608375337 0.7441486510630695
# 17 0.012576729902095404 0.011909818111194504 0.7488535524983622
# 18 0.012348428426238886 0.011800064105126592 0.7493895539276993
# 19 0.012195949062558645 0.011565878200862143 0.7539157882198797
# 20 0.01198268302248574 0.011403437828024228 0.7651718182359597
# 21 0.011778613966680347 0.011224745917651388 0.7677922696682746
# 22 0.01160396447881555 0.011076264331738155 0.7706509439580728
# 23 0.011468004793523145 0.01088951254884402 0.771722946816747
# 24 0.011282672889887772 0.01079868401090304 0.7752962896789947
# 25 0.011163319140255682 0.010592016039623155 0.7813709725448157

# %%
"""
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

gru_model = NN_Model(model=GRU(pretrained_weights, le_vocab, embed_size=300, hidden_size=128),
                     criterion=nn.CrossEntropyLoss(),
                     optim=optim.Adam
                    )

gru_model.fit(train_loader, valid_loader, epochs=25)
"""
# Out:
# "\ndevice = torch.device('cuda' if torch.cuda.is_available() else 'cpu')\n\ngru_model = NN_Model(model=GRU(pretrained_weights, le_vocab, embed_size=300, hidden_size=128),\n                     criterion=nn.CrossEntropyLoss(),\n                     optim=optim.Adam\n                    )\n\ngru_model.fit(train_loader, valid_loader, epochs=25)\n"

# %%
X[:30]
# Out:
# [[1, 'Men', 'men', 'NOUN'],
#  [2, 's', 's', 'PART'],
#  [3, 'and', 'and', 'CONJ'],
#  [4, 'Boys', 'boy', 'NOUN'],
#  [5, 'Barbers', 'barber', 'NOUN'],
#  [6, ',', ',', 'PUNCT'],
#  [7, 'on', 'on', 'ADP'],
#  [8, 'the', 'the', 'DET'],
#  [9, 'number', 'number', 'NOUN'],
#  [10, '9', '9', 'NUM'],
#  [11, 'Bus', 'bus', 'NOUN'],
#  [12, 'route', 'route', 'NOUN'],
#  [13, '.', '.', 'PUNCT'],
#  [14, '<eos>', '', ''],
#  [1, 'I', 'i', 'PRON'],
#  [2, 'was', 'be', 'AUX'],
#  [3, 'told', 'tell', 'VERB'],
#  [4, 'management', 'management', 'NOUN'],
#  [5, 'would', 'would', 'AUX'],
#  [6, 'call', 'call', 'VERB'],
#  [7, 'me', 'me', 'PRON'],
#  [8, 'back', 'back', 'ADP'],
#  [9, 'but', 'but', 'CONJ'],
#  [10, 'still', 'still', 'ADV'],
#  [11, 'waiting', 'wait', 'VERB'],
#  [12, 'for', 'for', 'ADP'],
#  [13, 'that', 'that', 'DET'],
#  [14, 'call', 'call', 'NOUN'],
#  [15, '.', '.', 'PUNCT'],
#  [16, '<eos>', '', '']]

# %%
def transform_test(le_vocab, le, X, y=None, max_len=16):
    vocab = [[text, pos] for _, text, _, pos in X]
    #int_texts = le_vocab.transform(vocab)
    #int_labels = le.transform(y)
    int_texts = [[le_vocab[word], le_pos[pos]] for word, pos in vocab]
    int_labels = [le[yi] for yi in y]
    
    def encode_sentence(int_texts, int_labels):
        temp_x, temp_y, final_y, final_x = [], [], [], []
        #eos_symbol = le_vocab.transform(['<eos>'])
        eos_symbol = le_vocab['<eos>']
        for x, y in zip(int_texts, int_labels) :
            temp_x.append(x)
            temp_y.append(y)
            if x[0] == eos_symbol :
                final_x.append(temp_x)
                final_y.append(temp_y)
                temp_x = []
                temp_y = []
        
        X = torch.zeros(len(final_x), max_len, 2).long()
        Y = torch.zeros(len(final_y), max_len).long()
        for i, (text, label) in enumerate(zip(final_x, final_y)):
            length = min(max_len, len(text))
            X[i,:length] = torch.LongTensor(text[:length])
            Y[i,:length] = torch.LongTensor(label[:length])
        
        #print(len(int_texts))
        #print(len(final_x))
        #print(X.size())
        
        return X, Y

    #print(len(int_texts))
    #print(len(int_texts_val))
    
    X_test, Y_test = encode_sentence(int_texts, int_labels)
    
    return X_test, Y_test


"""
def transform_test(le_vocab, le, X, y=None, max_len=16):
    vocab = [text for _, text, _, _ in X]
    #int_texts = le_vocab.transform(vocab)
    #int_labels = le.transform(y)
    int_texts = [le_vocab[word] for word in vocab]
    int_labels = [le[yi] for yi in y]
    
    
    def encode_sentence(int_texts, int_labels):
        temp_x, temp_y, final_y, final_x = [], [], [], []
        #eos_symbol = le_vocab.transform(['<eos>'])
        eos_symbol = le_vocab['<eos>']
        for x, y in zip(int_texts, int_labels) :
            temp_x.append(x)
            temp_y.append(y)
            if x == eos_symbol :
                final_x.append(temp_x)
                final_y.append(temp_y)
                temp_x = []
                temp_y = []
        
        X = torch.zeros(len(final_x), max_len).long()
        Y = torch.zeros(len(final_y), max_len).long()
        for i, (text, label) in enumerate(zip(final_x, final_y)):
            length = min(max_len, len(text))
            X[i,:length] = torch.LongTensor(text[:length])
            Y[i,:length] = torch.LongTensor(label[:length])
        
        #print(len(int_texts))
        #print(len(final_x))
        #print(X.size())
        
        return X, Y

    #print(len(int_texts))
    #print(len(int_texts_val))
    
    X_test, Y_test = encode_sentence(int_texts, int_labels)
    
    return X_test, Y_test
"""

def align_pred(X_orig, y_pred, le):
    y_trf_pred = []
    i_y = 0
    i = 0
    max_i = y_pred.size(1)
    is_first = True
    
    for xi in X_orig:
        if (not is_first) and xi[0] == 1:
            i_y += 1
            i = 0
        
        if i >= max_i:
            next_pred = le['']
        else:
            next_pred = y_pred[i_y][i].item()
        
        y_trf_pred.append( next_pred )
        i += 1
        is_first = False
    return y_trf_pred

# %%
X_test, y_test = transform_test(le_vocab, le, X[:30], y[:30])
#print(X_test.size())
gru_model.predict(X_test)
# Out:
# tensor([[ 1,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  4,  2,  0,  0,  0],
#         [ 2, 15,  6,  1,  2,  6,  2,  2,  2,  2, 19,  2,  2,  2,  2,  0]])

# %%
print(X_test)
print(y[:10])
print(y_test)
# Out:
# tensor([[[ 1,  0],
#          [ 2,  1],
#          [ 3,  2],
#          [ 4,  0],
#          [ 5,  0],
#          [ 6,  3],
#          [ 7,  4],
#          [ 8,  5],
#          [ 9,  0],
#          [10,  6],
#          [11,  0],
#          [12,  0],
#          [13,  3],
#          [ 0,  7],
#          [ 0,  0],
#          [ 0,  0]],
#
#         [[14,  8],
#          [15,  9],
#          [16, 10],
#          [17,  0],
#          [18,  9],
#          [19, 10],
#          [20,  8],
#          [21,  4],
#          [22,  2],
#          [23, 11],
#          [24, 10],
#          [25,  4],
#          [26,  5],
#          [19,  0],
#          [13,  3],
#          [ 0,  7]]])
# ['n.group', '', '', '', '', '', '', '', 'n.communication', '']
# tensor([[1, 2, 2, 2, 2, 2, 2, 2, 3, 2, 4, 5, 2, 0, 0, 0],
#         [2, 2, 6, 1, 2, 6, 2, 2, 2, 2, 7, 2, 2, 8, 2, 0]])

# %%
#gru_model.score(X_test, y_test, le.transform(['<eos>'])[0])
#gru_model.score(X_test, y_test, le.transform([''])[0])
gru_model.score(X_test, y_test, le[''])
# Out:
# 32
# (0.7272727272727273, 0.6153846153846154, 0.6666666666666667, 0.8125)

# %%
rev_le = {v: k for k, v in le.items()}
rev_le[0]
# Out:
# '<eos>'

# %%
X_val_enc, y_val_enc = transform_test(le_vocab, le, X_val, y_val)
rev_le = {v: k for k, v in le.items()}

y_hat_val = gru_model.predict(X_val_enc)
y_hat_val_align = align_pred(X_val, y_hat_val, le)
y_hat_val_align = [rev_le[yi] for yi in y_hat_val_align] # Decode
write_data(X_val, y_hat_val_align, 'val.pred')

# %%
print(len(X_val))
y_hat_val.size()
# Out:
# 23575
# torch.Size([1440, 16])

# %%
# !python ../dimsum-data-1.5/scripts/dimsumeval.py val.gold val.pred
# Out:
# 23
# 23
# 23
# TEST 23 [('They', 'O', 'O'), ('might', 'O', 'O'), ('want', 'O', 'O'), ('to', 'O', 'O'), ('change', 'O', 'O'), ('the', 'O', 'O'), ('name', 'O', 'O'), ('to', 'O', 'O'), ('reflect', 'O', 'O'), ('the', 'O', 'O'), ('new', 'O', 'O'), ('yorkedness', 'O', 'O'), ('of', 'O', 'O'), ('the', 'O', 'O'), ('pizza', 'O', 'O'), (',', 'O', 'O'), ('scrummy', 'O', 'O'), ('yummy', 'O', 'O'), ('sounds', 'O', 'O'), ('gimmicky', 'O', 'O'), ('to', 'O', 'O'), ('me', 'O', 'O'), ('.', 'O', 'O')]
# 33
# 33
# 33
# TEST 33 [('@_liinds', 'O', 'O'), ('yehhh', 'O', 'O'), ('!', 'O', 'O'), ('i', 'O', 'O'), ('thinkk', 'O', 'O'), ('i', 'O', 'O'), ('got', 'O', 'O'), ('it', 'O', 'O'), ('(', 'O', 'O'), (':', 'O', 'O'), ('the', 'O', 'O'), ('guy', 'O', 'O'), ('told', 'O', 'O'), ('me', 'O', 'O'), ("'ll", 'O', 'O'), ('call', 'O', 'O'), ('me', 'O', 'O'), ('when', 'O', 'O'), ('he', 'O', 'O'), ('gets', 'O', 'O'), ('my', 'O', 'O'), ('application', 'O', 'O'), ('to', 'O', 'O'), ('the', 'O', 'O'), ('person', 'O', 'O'), ('!', 'O', 'O'), ('its', 'O', 'O'), ('the', 'O', 'O'), ('one', 'O', 'O'), ('in', 'O', 'O'), ('herold', 'O', 'O'), ('square', 'O', 'O'), ('!', 'O', 'O')]
# 4
# 4
# 4
# TEST 4 [('Will', 'O', 'O'), ('definitely', 'O', 'O'), ('return', 'O', 'O'), ('.', 'O', 'O')]
# 23
# 23
# 23
# TEST 23 [('Before', 'O', 'O'), ('coming', 'O', 'O'), ('to', 'O', 'O'), ('Acupuncture', 'O', 'O'), ('DOCTOR', 'O', 'O'), ('I', 'O', 'O'), ('was', 'O', 'O'), ('a', 'O', 'O'), ('big', 'O', 'O'), ('baby', 'O', 'O'), ('about', 'O', 'O'), ('needles', 'O', 'O'), ('and', 'O', 'O'), ('only', 'O', 'O'), ('came', 'O', 'O'), ('because', 'O', 'O'), ('my', 'O', 'O'), ('boyfriend', 'O', 'O'), ("'s", 'O', 'O'), ('aunt', 'O', 'O'), ('recommended', 'O', 'O'), ('it', 'O', 'O'), ('.', 'O', 'O')]
# 37
# 37
# 37
# TEST 37 [('~', 'O', 'O'), ('It', 'O', 'O'), ('took', 'O', 'O'), ('over', 'O', 'O'), ('40', 'O', 'O'), ('mins', 'O', 'O'), ('to', 'O', 'O'), ('be', 'O', 'O'), ('taken', 'O', 'O'), ('to', 'O', 'O'), ('our', 'O', 'O'), ('table', 'O', 'O'), (',', 'O', 'O'), ('once', 'O', 'O'), ('there', 'O', 'O'), ('it', 'O', 'O'), ('took', 'O', 'O'), ('another', 'O', 'O'), ('20', 'O', 'O'), ('mins', 'O', 'O'), ('to', 'O', 'O'), ('get', 'O', 'O'), ('our', 'O', 'O'), ('orders', 'O', 'O'), ('and', 'O', 'O'), ('a', 'O', 'O'), ('further', 'O', 'O'), ('45', 'O', 'O'), ('mins', 'O', 'O'), ('till', 'O', 'O'), ('our', 'O', 'O'), ('starters', 'O', 'O'), ('landed', 'O', 'O'), ('on', 'O', 'O'), ('our', 'O', 'O'), ('table', 'O', 'O'), ('.', 'O', 'O')]
# 5
# 5
# 5
# TEST 5 [('Excellent', 'O', 'O'), ('Service', 'O', 'O'), ('and', 'O', 'O'), ('Reasonable', 'O', 'O'), ('Prices', 'O', 'O')]
# 8
# 8
# 8
# TEST 8 [('EVERYTHING', 'O', 'O'), ('IN', 'O', 'O'), ('HERE', 'O', 'O'), ('SEEMS', 'O', 'O'), ('TO', 'O', 'O'), ('AMAZE', 'O', 'O'), ('ME', 'O', 'O'), ('!!!', 'O', 'O')]
# 22
# 22
# 22
# TEST 22 [('You', 'O', 'O'), ("'d", 'O', 'O'), ('think', 'O', 'O'), ('they', 'O', 'O'), ('would', 'O', 'O'), ('do', 'O', 'O'), ('a', 'O', 'O'), ('good', 'O', 'O'), ('job', 'O', 'O'), ('but', 'O', 'O'), ('they', 'O', 'O'), ('do', 'O', 'O'), ("n't", 'O', 'O'), ('care', 'O', 'O'), ('unless', 'O', 'O'), ('they', 'O', 'O'), ('are', 'O', 'O'), ('getting', 'O', 'O'), ('paid', 'O', 'O'), ('full', 'O', 'O'), ('price', 'O', 'O'), ('.', 'O', 'O')]
# 5
# 5
# 5
# TEST 5 [('It', 'O', 'O'), ("'s", 'O', 'O'), ('pretty', 'O', 'O'), ('ridiculous', 'O', 'O'), ('!', 'O', 'O')]
# 9
# 9
# 9
# TEST 9 [('great', 'O', 'O'), ('service', 'O', 'O'), ('/', 'O', 'O'), ('deals', 'O', 'O'), ('-', 'O', 'O'), ('support', 'O', 'O'), ('this', 'O', 'O'), ('local', 'O', 'O'), ('business', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('it', 'O', 'O'), ('was', 'O', 'O'), ('worth', 'O', 'O'), ('of', 'O', 'O'), ('the', 'O', 'O'), ('ride', 'O', 'O'), ('more', 'O', 'O'), ('than', 'O', 'O'), ('an', 'O', 'O'), ('hour', 'O', 'O'), ('...', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('They', 'O', 'O'), ('do', 'O', 'O'), ("n't", 'O', 'O'), ('speak', 'O', 'O'), ('the', 'O', 'O'), ('best', 'O', 'O'), ('English', 'O', 'O'), ('but', 'O', 'O'), ('enough', 'O', 'O'), ('to', 'O', 'O'), ('get', 'O', 'O'), ('by', 'O', 'O'), ('.', 'O', 'O')]
# 18
# 18
# 18
# TEST 18 [('I', 'O', 'O'), ("'m", 'O', 'O'), ('so', 'O', 'O'), ('addicted', 'O', 'O'), ('to', 'O', 'O'), ('Twitter', 'O', 'O'), ('now', 'O', 'O'), ('that', 'O', 'O'), ('I', 'O', 'O'), ('can', 'O', 'O'), ('tweet', 'O', 'O'), ('all', 'O', 'O'), ('the', 'O', 'O'), ('time', 'O', 'O'), ('.', 'O', 'O'), ('Not', 'O', 'O'), ('good', 'O', 'O'), ('.', 'O', 'O')]
# 10
# 10
# 10
# TEST 10 [('The', 'O', 'O'), ('shop', 'O', 'O'), ('is', 'O', 'O'), ('located', 'O', 'O'), ('just', 'O', 'O'), ('off', 'O', 'O'), ('the', 'O', 'O'), ('river', 'O', 'O'), ('road', 'O', 'O'), ('.', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('I', 'O', 'O'), ('work', 'O', 'O'), ('2', 'O', 'O'), ('hours', 'O', 'O'), ('away', 'O', 'O'), ('but', 'O', 'O'), ('offered', 'O', 'O'), ('my', 'O', 'O'), ('card', 'O', 'O'), ('over', 'O', 'O'), ('the', 'O', 'O'), ('phone', 'O', 'O'), ('.', 'O', 'O')]
# 6
# 6
# 6
# TEST 6 [('We', 'O', 'O'), ('should', 'O', 'O'), ('have', 'O', 'O'), ('left', 'O', 'O'), ('then', 'O', 'O'), ('.', 'O', 'O')]
# 24
# 24
# 24
# TEST 24 [('Saw', 'O', 'O'), ('Ip-Man', 'O', 'O'), ('2', 'O', 'O'), ('at', 'O', 'O'), ('the', 'O', 'O'), ('Cinemark', 'O', 'O'), ('in', 'O', 'O'), ('Long', 'O', 'O'), ('Beach', 'O', 'O'), ('last', 'O', 'O'), ('night', 'O', 'O'), ('.', 'O', 'O'), ('That', 'O', 'O'), ('movie', 'O', 'O'), ('was', 'O', 'O'), ('dope', 'O', 'O'), ('!!', 'O', 'O'), ('I', 'O', 'O'), ('love', 'O', 'O'), ('goin', 'O', 'O'), ('to', 'O', 'O'), ('the', 'O', 'O'), ('movies', 'O', 'O'), ('.', 'O', 'O')]
# 2
# 2
# 2
# TEST 2 [('Channel', 'O', 'O'), ('Guide', 'O', 'O')]
# 16
# 16
# 16
# TEST 16 [('After', 'O', 'O'), ('a', 'O', 'O'), ('good', 'O', 'O'), ('few', 'O', 'O'), ('minutes', 'O', 'O'), (',', 'O', 'O'), ('he', 'O', 'O'), ('asked', 'O', 'O'), (':', 'O', 'O'), ('"', 'O', 'O'), ('what', 'O', 'O'), ('do', 'O', 'O'), ('you', 'O', 'O'), ('want', 'O', 'O'), ('?', 'O', 'O'), ('"', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [('What', 'O', 'O'), ('I', 'O', 'O'), ('like', 'O', 'O'), ('most', 'O', 'O'), ('about', 'O', 'O'), ('Dr.', 'O', 'O'), ('Liau', 'O', 'O'), ('is', 'O', 'O'), ('that', 'O', 'O'), ('she', 'O', 'O'), ('is', 'O', 'O'), ('very', 'O', 'O'), ('caring', 'O', 'O'), ('.', 'O', 'O')]
# 5
# 5
# 5
# TEST 5 [('The', 'O', 'O'), ('best', 'O', 'O'), ('photographer', 'O', 'O'), ('in', 'O', 'O'), ('Miami', 'O', 'O')]
# 7
# 7
# 7
# TEST 7 [('Pretty', 'O', 'O'), ('spendy', 'O', 'O'), ('for', 'O', 'O'), ('really', 'O', 'O'), ('not', 'O', 'O'), ('great', 'O', 'O'), ('quality', 'O', 'O')]
# 3
# 3
# 3
# TEST 3 [('Luv', 'O', 'O'), ('always', 'O', 'O'), ('..', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('Oh', 'O', 'O'), (',', 'O', 'O'), ('yes', 'O', 'O'), (',', 'O', 'O'), ('the', 'O', 'O'), ('chocolate', 'O', 'O'), ('semifreddo', 'O', 'O'), ('was', 'O', 'O'), ('quite', 'O', 'O'), ('good', 'O', 'O'), ('.', 'O', 'O')]
# 23
# 23
# 23
# TEST 23 [('I', 'O', 'O'), ('suggest', 'O', 'O'), ('you', 'O', 'O'), ('go', 'O', 'O'), ('up', 'O', 'O'), ('to', 'O', 'O'), ('Raging', 'O', 'O'), ('Taco', 'O', 'O'), ('&', 'O', 'O'), ('Raging', 'O', 'O'), ('Burrito', 'O', 'O'), ('a', 'O', 'O'), ('couple', 'O', 'O'), ('of', 'O', 'O'), ('blocks', 'O', 'O'), ('up', 'O', 'O'), ('the', 'O', 'O'), ('street', 'O', 'O'), ('or', 'O', 'O'), ('even', 'O', 'O'), ('Taco', 'O', 'O'), ('Mac', 'O', 'O'), ('.', 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('She', 'O', 'O'), ('makes', 'O', 'O'), ('you', 'O', 'O'), ('feel', 'O', 'O'), ('like', 'O', 'O'), ('you', 'O', 'O'), ('are', 'O', 'O'), ('the', 'O', 'O'), ('most', 'O', 'O'), ('important', 'O', 'O'), ('person', 'O', 'O'), ('in', 'O', 'O'), ('the', 'O', 'O'), ('world', 'O', 'O'), ('.', 'O', 'O')]
# 28
# 28
# 28
# TEST 28 [('***', 'O', 'O'), ('#CCC', 'O', 'O'), ('Butterfly', 'O', 'O'), ('?????', 'O', 'O'), ('Asks', 'O', 'O'), ('........', 'O', 'O'), ('WHAT', 'O', 'O'), ('AM', 'O', 'O'), ('I', 'O', 'O'), ('????', 'O', 'O'), ('***', 'O', 'O'), ('Riddle', 'O', 'O'), ('me', 'O', 'O'), ('this', 'O', 'O'), (',', 'O', 'O'), ('Riddle', 'O', 'O'), ('me', 'O', 'O'), ('that', 'O', 'O'), ('A', 'O', 'O'), ('Quiz', 'O', 'O'), ('for', 'O', 'O'), ('you', 'O', 'O'), (',', 'O', 'O'), ('so', 'O', 'O'), ('get', 'O', 'O'), ('on', 'O', 'O'), ('...', 'O', 'O'), ('URL', 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('their', 'O', 'O'), ('pizza', 'O', 'O'), ('was', 'O', 'O'), ('a', 'O', 'O'), ('little', 'O', 'O'), ('salty', 'O', 'O'), ('for', 'O', 'O'), ('me', 'O', 'O'), (',', 'O', 'O'), ('but', 'O', 'O'), ('it', 'O', 'O'), ('s', 'O', 'O'), ('still', 'O', 'O'), ('good', 'O', 'O'), ('.', 'O', 'O')]
# 27
# 27
# 27
# TEST 27 [('You', 'O', 'O'), ('have', 'O', 'O'), ('to', 'O', 'O'), ('bring', 'O', 'O'), ('in', 'O', 'O'), ('your', 'O', 'O'), ('own', 'O', 'O'), ('models', 'O', 'O'), ('and', 'O', 'O'), ('they', 'O', 'O'), ('have', 'O', 'O'), ('to', 'O', 'O'), ('pay', 'O', 'O'), ('for', 'O', 'O'), ('you', 'O', 'O'), ('to', 'O', 'O'), ('use', 'O', 'O'), ('them', 'O', 'O'), ('if', 'O', 'O'), ('you', 'O', 'O'), ('do', 'O', 'O'), ('nt', 'O', 'O'), ('then', 'O', 'O'), ('you', 'O', 'O'), ('can', 'O', 'O'), ('graduate', 'O', 'O'), ('!', 'O', 'O')]
# 10
# 10
# 10
# TEST 10 [('80', 'O', 'O'), ('degrees', 'O', 'O'), ('in', 'O', 'O'), ('SF', 'O', 'O'), ('yesterday', 'O', 'O'), (',', 'O', 'O'), ('sorry', 'O', 'O'), ('east', 'O', 'O'), ('coasters', 'O', 'O'), ('!', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [('I', 'O', 'O'), ('recently', 'O', 'O'), ('threw', 'O', 'O'), ('a', 'O', 'O'), ('surprise', 'O', 'O'), ('birthday', 'O', 'O'), ('party', 'O', 'O'), ('for', 'O', 'O'), ('my', 'O', 'O'), ('wife', 'O', 'O'), ('at', 'O', 'O'), ('Fraiser', 'O', 'O'), ("'s", 'O', 'O'), ('.', 'O', 'O')]
# 8
# 8
# 8
# TEST 8 [('Senior', 'O', 'O'), ('Accountant/Financial', 'O', 'O'), ('controller(ACCA', 'O', 'O'), (')', 'O', 'O'), ('-', 'O', 'O'), ('#Qatar', 'O', 'O'), ('#Jobs', 'O', 'O'), ('URL', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('She', 'O', 'O'), ('says', 'O', 'O'), (',', 'O', 'O'), ('Is', 'O', 'O'), ('that', 'O', 'O'), ('17th', 'O', 'O'), ('like', 'O', 'O'), ('over', 'O', 'O'), ('past', 'O', 'O'), ('broad', 'O', 'O'), ('.', 'O', 'O')]
# 7
# 7
# 7
# TEST 7 [('Both', 'O', 'O'), ('Tina', 'O', 'O'), ('and', 'O', 'O'), ('Vicky', 'O', 'O'), ('are', 'O', 'O'), ('excellent', 'O', 'O'), ('.', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('At', 'O', 'O'), ('the', 'O', 'O'), ('front', 'O', 'O'), ('door', 'O', 'O'), ('of', 'O', 'O'), ('his', 'O', 'O'), ('office', 'O', 'O'), (',', 'O', 'O'), ('I', 'O', 'O'), ('nearly', 'O', 'O'), ('turned', 'O', 'O'), ('around', 'O', 'O'), ('.', 'O', 'O')]
# 7
# 7
# 7
# TEST 7 [('Fantastic', 'O', 'O'), ('Place', 'O', 'O'), ('to', 'O', 'O'), ('buy', 'O', 'O'), ('your', 'O', 'O'), ('next', 'O', 'O'), ('vehicle', 'O', 'O')]
# 26
# 26
# 26
# TEST 26 [('RT', 'O', 'O'), ('@therbertson', 'O', 'O'), (':', 'O', 'O'), ('Just', 'O', 'O'), ('saw', 'O', 'O'), ('the', 'O', 'O'), ('worst', 'O', 'O'), ('movie', 'O', 'O'), ('in', 'O', 'O'), ('years', 'O', 'O'), ('...', 'O', 'O'), ('Piranha', 'O', 'O'), ('3D', 'O', 'O'), ('just', 'O', 'O'), ('exceeded', 'O', 'O'), ('the', 'O', 'O'), ('limits', 'O', 'O'), ('of', 'O', 'O'), ('crappyness', 'O', 'O'), ('.', 'O', 'O'), ('|', 'O', 'O'), ('Glad', 'O', 'O'), ('you', 'O', 'O'), ('enjoyed', 'O', 'O'), ('it', 'O', 'O'), ('.', 'O', 'O')]
# 8
# 8
# 8
# TEST 8 [('We', 'O', 'O'), ('were', 'O', 'O'), ('also', 'O', 'O'), ('served', 'O', 'O'), ('salad', 'O', 'O'), ('and', 'O', 'O'), ('soda', 'O', 'O'), ('.', 'O', 'O')]
# 9
# 9
# 9
# TEST 9 [('Bonfire', 'O', 'O'), ('tonite', 'O', 'O'), ('.', 'O', 'O'), ('All', 'O', 'O'), ('are', 'O', 'O'), ('welcome', 'O', 'O'), (',', 'O', 'O'), ('joe', 'O', 'O'), ('included', 'O', 'O')]
# 4
# 4
# 4
# TEST 4 [('Not', 'O', 'O'), ('enough', 'O', 'O'), ('seating', 'O', 'O'), ('.', 'O', 'O')]
# 2
# 2
# 2
# TEST 2 [('spot', 'O', 'O'), ('on', 'O', 'O')]
# 7
# 7
# 7
# TEST 7 [('The', 'O', 'O'), ('instructor', 'O', 'O'), ('did', 'O', 'O'), ('not', 'O', 'O'), ('show', 'O', 'O'), ('up', 'O', 'O'), ('!', 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('Our', 'O', 'O'), ('friend', 'O', 'O'), ('is', 'O', 'O'), ('a', 'O', 'O'), ('world', 'O', 'O'), ('traveler', 'O', 'O'), ('and', 'O', 'O'), ('loves', 'O', 'O'), ('unpretentious', 'O', 'O'), ('dining', 'O', 'O'), ('experiences', 'O', 'O'), ('and', 'O', 'O'), ('inspired', 'O', 'O'), ('food', 'O', 'O'), ('.', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [('The', 'O', 'O'), ('price', 'O', 'O'), ('they', 'O', 'O'), ('gave', 'O', 'O'), ('was', 'O', 'O'), ('good', 'O', 'O'), ('so', 'O', 'O'), ('I', 'O', 'O'), ('said', 'O', 'O'), ('hey', 'O', 'O'), ('this', 'O', 'O'), ('seems', 'O', 'O'), ('great', 'O', 'O'), ('.', 'O', 'O')]
# 6
# 6
# 6
# TEST 6 [('The', 'O', 'O'), ('architecture', 'O', 'O'), ('is', 'O', 'O'), ('simplz', 'O', 'O'), ('splendid', 'O', 'O'), ('.', 'O', 'O')]
# 21
# 21
# 21
# TEST 21 [('Check', 'O', 'O'), ('this', 'O', 'O'), ('video', 'O', 'O'), ('out', 'O', 'O'), ('--', 'O', 'O'), ('Three', 'O', 'O'), ('Days', 'O', 'O'), ('Grace', 'O', 'O'), ('-', 'O', 'O'), ('Break', 'O', 'O'), ('(', 'O', 'O'), ('Official', 'O', 'O'), ('Music', 'O', 'O'), ('Video', 'O', 'O'), (')', 'O', 'O'), ('[', 'O', 'O'), ('HQ', 'O', 'O'), (']', 'O', 'O'), ('http://t.co/GOwCLQJ', 'O', 'O'), ('via', 'O', 'O'), ('@youtube', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [('Encino', 'O', 'O'), ('has', 'O', 'O'), ('been', 'O', 'O'), ('blessed', 'O', 'O'), ('by', 'O', 'O'), ('the', 'O', 'O'), ('opening', 'O', 'O'), ('of', 'O', 'O'), ('this', 'O', 'O'), ('smoke', 'O', 'O'), ('shop', 'O', 'O'), ('most', 'O', 'O'), ('definately', 'O', 'O'), ('.', 'O', 'O')]
# 22
# 22
# 22
# TEST 22 [('It', 'O', 'O'), ("'s", 'O', 'O'), ('unfortunate', 'O', 'O'), ('that', 'O', 'O'), ('bmil', 'O', 'O'), ('believed', 'O', 'O'), ('that', 'O', 'O'), ('his', 'O', 'O'), ("'", 'O', 'O'), ('perfect', 'O', 'O'), ("'", 'O', 'O'), ('dog', 'O', 'O'), ('was', 'O', 'O'), ('not', 'O', 'O'), ('given', 'O', 'O'), ('the', 'O', 'O'), ('right', 'O', 'O'), ('opportunity', 'O', 'O'), ('to', 'O', 'O'), ('prove', 'O', 'O'), ('himself', 'O', 'O'), ('.', 'O', 'O')]
# 24
# 24
# 24
# TEST 24 [('Pets', 'O', 'O'), ('Discount', 'O', 'O'), ('has', 'O', 'O'), ('lovely', 'O', 'O'), ('employees', 'O', 'O'), (',', 'O', 'O'), ('a', 'O', 'O'), ('wonderful', 'O', 'O'), ('grooming', 'O', 'O'), ('service', 'O', 'O'), (',', 'O', 'O'), ('and', 'O', 'O'), ('everything', 'O', 'O'), ('I', 'O', 'O'), ('need', 'O', 'O'), ('to', 'O', 'O'), ('keep', 'O', 'O'), ('my', 'O', 'O'), ('dog', 'O', 'O'), ('in', 'O', 'O'), ('tip', 'O', 'O'), ('top', 'O', 'O'), ('condition', 'O', 'O'), ('!', 'O', 'O')]
# 19
# 19
# 19
# TEST 19 [('The', 'O', 'O'), ('Rams', 'O', 'O'), (',', 'O', 'O'), ('the', 'O', 'O'), ('VCU', 'O', 'O'), ('sports', 'O', 'O'), ('team', 'O', 'O'), (',', 'O', 'O'), ('also', 'O', 'O'), ('made', 'O', 'O'), ('the', 'O', 'O'), ('NCAA', 'O', 'O'), ('Final', 'O', 'O'), ('4', 'O', 'O'), ('this', 'O', 'O'), ('year', 'O', 'O'), (',', 'O', 'O'), ('too', 'O', 'O'), ('!', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('RT', 'O', 'O'), ('@DesignerDepot', 'O', 'O'), (':', 'O', 'O'), ('Minimalist', 'O', 'O'), ('Web', 'O', 'O'), ('Design', 'O', 'O'), (':', 'O', 'O'), ('When', 'O', 'O'), ('Less', 'O', 'O'), ('is', 'O', 'O'), ('More', 'O', 'O'), ('-', 'O', 'O'), ('http://ow.ly/2FwyX', 'O', 'O')]
# 18
# 18
# 18
# TEST 18 [('I', 'O', 'O'), ('think', 'O', 'O'), ('they', 'O', 'O'), ('may', 'O', 'O'), ('even', 'O', 'O'), ('be', 'O', 'O'), ('better', 'O', 'O'), ('than', 'O', 'O'), ('the', 'O', 'O'), ('pair', 'O', 'O'), ('I', 'O', 'O'), ('have', 'O', 'O'), ('been', 'O', 'O'), ('using', 'O', 'O'), ('this', 'O', 'O'), ('past', 'O', 'O'), ('year', 'O', 'O'), ('!', 'O', 'O')]
# 29
# 29
# 29
# TEST 29 [('the', 'O', 'O'), ('food', 'O', 'O'), ('was', 'O', 'O'), ('horrible', 'O', 'O'), ('not', 'O', 'O'), ('cooked', 'O', 'O'), ('like', 'O', 'O'), ('it', 'O', 'O'), ('should', 'O', 'O'), ('be', 'O', 'O'), (',', 'O', 'O'), ('they', 'O', 'O'), ('got', 'O', 'O'), ('the', 'O', 'O'), ('order', 'O', 'O'), ('wrong', 'O', 'O'), ('on', 'O', 'O'), ('a', 'O', 'O'), ('number', 'O', 'O'), ('of', 'O', 'O'), ('occasions', 'O', 'O'), (',', 'O', 'O'), ('and', 'O', 'O'), ('once', 'O', 'O'), ('forgot', 'O', 'O'), ('about', 'O', 'O'), ('my', 'O', 'O'), ('order', 'O', 'O'), ('.', 'O', 'O')]
# 10
# 10
# 10
# TEST 10 [('Dr.', 'O', 'O'), ('Strzalka', 'O', 'O'), ('at', 'O', 'O'), ('Flagship', 'O', 'O'), ('CVTS', 'O', 'O'), ('is', 'O', 'O'), ('not', 'O', 'O'), ('a', 'O', 'O'), ('good', 'O', 'O'), ('doctor', 'O', 'O')]
# 9
# 9
# 9
# TEST 9 [('Nice', 'O', 'O'), ('little', 'O', 'O'), ('locally', 'O', 'O'), ('owned', 'O', 'O'), ('greek', 'O', 'O'), ('bar', 'O', 'O'), ('and', 'O', 'O'), ('grill', 'O', 'O'), ('.', 'O', 'O')]
# 7
# 7
# 7
# TEST 7 [('Ice', 'O', 'O'), ('cold', 'O', 'O'), ('beer', 'O', 'O'), ('and', 'O', 'O'), ('good', 'O', 'O'), ('prices', 'O', 'O'), ('.', 'O', 'O')]
# 3
# 3
# 3
# TEST 3 [('Room', 'O', 'O'), ('ok', 'O', 'O'), ('.', 'O', 'O')]
# 4
# 4
# 4
# TEST 4 [('hope', 'O', 'O'), ('this', 'O', 'O'), ('helps', 'O', 'O'), ('!!', 'O', 'O')]
# 30
# 30
# 30
# TEST 30 [('@Dc_Luvs_Swift', 'O', 'O'), ('randomly', 'O', 'O'), ('that', 'O', 'O'), ('just', 'O', 'O'), ('made', 'O', 'O'), ('me', 'O', 'O'), ('smile', 'O', 'O'), (':D', 'O', 'O'), ('do', 'O', 'O'), ("n't", 'O', 'O'), ('ring', 'O', 'O'), ('the', 'O', 'O'), ('bell', 'O', 'O'), ('tweet', 'O', 'O'), ('me', 'O', 'O'), ('when', 'O', 'O'), ('ur', 'O', 'O'), ('here', 'O', 'O'), ("'ll", 'O', 'O'), ('let', 'O', 'O'), ('u', 'O', 'O'), ('in', 'O', 'O'), (':D', 'O', 'O'), ('...', 'O', 'O'), ('that', 'O', 'O'), ('def', 'O', 'O'), ('would', 'O', 'O'), ('be', 'O', 'O'), ('awesome', 'O', 'O'), (':D', 'O', 'O')]
# 5
# 5
# 5
# TEST 5 [('Accurate', 'O', 'O'), ('check', 'O', 'O'), ('-', 'O', 'O'), ('out', 'O', 'O'), ('.', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [("#Syria's", 'O', 'O'), ('#Assad', 'O', 'O'), ('dismisses', 'O', 'O'), ('chemical', 'O', 'O'), ('weapon', 'O', 'O'), ('use', 'O', 'O'), ('as', 'O', 'O'), ('politically', 'O', 'O'), ('motivated', 'O', 'O'), ('-', 'O', 'O'), ('The', 'O', 'O'), ('Star', 'O', 'O'), ('Online', 'O', 'O'), ('URL', 'O', 'O')]
# 3
# 3
# 3
# TEST 3 [('Thanks', 'O', 'O'), ('Mark', 'O', 'O'), ('.', 'O', 'O')]
# 1
# 1
# 1
# TEST 1 [('teeth', 'O', 'O')]
# 20
# 20
# 20
# TEST 20 [('I', 'O', 'O'), ('spent', 'O', 'O'), ('$', 'O', 'O'), ('2300', 'O', 'O'), ('on', 'O', 'O'), ('the', 'O', 'O'), ('bedroom', 'O', 'O'), ('suite', 'O', 'O'), (',', 'O', 'O'), ('which', 'O', 'O'), ('was', 'O', 'O'), ('complete', 'O', 'O'), ('and', 'O', 'O'), ('excellent', 'O', 'O'), ('condition', 'O', 'O'), ('on', 'O', 'O'), ('the', 'O', 'O'), ('showroom', 'O', 'O'), ('floor', 'O', 'O'), ('.', 'O', 'O')]
# 7
# 7
# 7
# TEST 7 [('The', 'O', 'O'), ('owners', 'O', 'O'), ('were', 'O', 'O'), ('entertaining', 'O', 'O'), ('and', 'O', 'O'), ('gracious', 'O', 'O'), ('.', 'O', 'O')]
# 8
# 8
# 8
# TEST 8 [('4', 'O', 'O'), (')', 'O', 'O'), ('The', 'O', 'O'), ('business', 'O', 'O'), ('is', 'O', 'O'), ('very', 'O', 'O'), ('unorganized', 'O', 'O'), ('.', 'O', 'O')]
# 3
# 3
# 3
# TEST 3 [('Thanks', 'O', 'O'), ('From', 'O', 'O'), ('Bill', 'O', 'O')]
# 17
# 17
# 17
# TEST 17 [('I', 'O', 'O'), ('have', 'O', 'O'), ('to', 'O', 'O'), ('tell', 'O', 'O'), ('you', 'O', 'O'), ('that', 'O', 'O'), ('I', 'O', 'O'), ('have', 'O', 'O'), ("n't", 'O', 'O'), ('had', 'O', 'O'), ('one', 'O', 'O'), ('and', 'O', 'O'), ('do', 'O', 'O'), ("n't", 'O', 'O'), ('want', 'O', 'O'), ('one', 'O', 'O'), ('.', 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('We', 'O', 'O'), ('stopped', 'O', 'O'), ('in', 'O', 'O'), ('and', 'O', 'O'), ('got', 'O', 'O'), ('some', 'O', 'O'), ('take', 'O', 'O'), ('out', 'O', 'O'), ('and', 'O', 'O'), ('can', 'O', 'O'), ('not', 'O', 'O'), ('stop', 'O', 'O'), ('going', 'O', 'O'), ('back', 'O', 'O'), ('.', 'O', 'O')]
# 2
# 2
# 2
# TEST 2 [('Horrible', 'O', 'O'), ('!', 'O', 'O')]
# 10
# 10
# 10
# TEST 10 [('I', 'O', 'O'), ('will', 'O', 'O'), ('not', 'O', 'O'), ('be', 'O', 'O'), ('visiting', 'O', 'O'), ('Mama', 'O', 'O'), ('Mia', 'O', 'O'), ("'s", 'O', 'O'), ('again', 'O', 'O'), ('.', 'O', 'O')]
# 3
# 3
# 3
# TEST 3 [('Suzanne', 'O', 'O'), (',', 'O', 'O'), ('Vancouver', 'O', 'O')]
# 29
# 29
# 29
# TEST 29 [('When', 'O', 'O'), ('I', 'O', 'O'), ('grow', 'O', 'O'), ('up', 'O', 'O'), (',', 'O', 'O'), ('I', 'O', 'O'), ('want', 'O', 'O'), ('to', 'O', 'O'), ('...', 'O', 'O'), ('URL', 'O', 'O'), ('from', 'O', 'O'), ('Seth', 'O', 'O'), ('Godin', 'O', 'O'), ('.', 'O', 'O'), ('You', 'O', 'O'), ("don't", 'O', 'O'), ('need', 'O', 'O'), ('to', 'O', 'O'), ('boil', 'O', 'O'), ('the', 'O', 'O'), ('ocean', 'O', 'O'), ('to', 'O', 'O'), ('change', 'O', 'O'), ('the', 'O', 'O'), ('world', 'O', 'O'), ('for', 'O', 'O'), ('the', 'O', 'O'), ('better', 'O', 'O'), ('.', 'O', 'O')]
# 8
# 8
# 8
# TEST 8 [('The', 'O', 'O'), ('best', 'O', 'O'), ('pilates', 'O', 'O'), ('on', 'O', 'O'), ('the', 'O', 'O'), ('Gold', 'O', 'O'), ('Coast', 'O', 'O'), ('!', 'O', 'O')]
# 33
# 33
# 33
# TEST 33 [('Called', 'O', 'O'), ('to', 'O', 'O'), ('check', 'O', 'O'), ('if', 'O', 'O'), ('they', 'O', 'O'), ('had', 'O', 'O'), ('a', 'O', 'O'), ('product', 'O', 'O'), ('I', 'O', 'O'), ("'ve", 'O', 'O'), ('been', 'O', 'O'), ('using', 'O', 'O'), ('on', 'O', 'O'), ('my', 'O', 'O'), ('dog', 'O', 'O'), ('for', 'O', 'O'), ('years', 'O', 'O'), ('...', 'O', 'O'), ('the', 'O', 'O'), ('boy', 'O', 'O'), ('who', 'O', 'O'), ('answered', 'O', 'O'), ('the', 'O', 'O'), ('phone', 'O', 'O'), ('could', 'O', 'O'), ("n't", 'O', 'O'), ('possibly', 'O', 'O'), ('have', 'O', 'O'), ('been', 'O', 'O'), ('ruder', 'O', 'O'), ('to', 'O', 'O'), ('me', 'O', 'O'), ('.', 'O', 'O')]
# 29
# 29
# 29
# TEST 29 [('RT', 'O', 'O'), ('@benisweird', 'O', 'O'), (':', 'O', 'O'), ('#FF', 'O', 'O'), ('Once', 'O', 'O'), ('upon', 'O', 'O'), ('a', 'O', 'O'), ('time', 'O', 'O'), ('@FredasaurusRex', 'O', 'O'), ('opened', 'O', 'O'), ('his', 'O', 'O'), ('mouth', 'O', 'O'), ('and', 'O', 'O'), ('the', 'O', 'O'), ('wind', 'O', 'O'), ('changed', 'O', 'O'), ('direction', 'O', 'O'), ('.', 'O', 'O'), ('Now', 'O', 'O'), ('he', 'O', 'O'), ("'s", 'O', 'O'), ('stuck', 'O', 'O'), ('like', 'O', 'O'), ('that', 'O', 'O'), ('.', 'O', 'O'), ('I', 'O', 'O'), ('find', 'O', 'O'), ('h', 'O', 'O'), ('...', 'O', 'O')]
# 5
# 5
# 5
# TEST 5 [('Best', 'O', 'O'), ('place', 'O', 'O'), ('to', 'O', 'O'), ('sleep', 'O', 'O'), ('!!!!!!!', 'O', 'O')]
# 6
# 6
# 6
# TEST 6 [('Rcommended', 'O', 'O'), ('by', 'O', 'O'), ('bees', 'O', 'O'), (',', 'O', 'O'), ('too', 'O', 'O'), ('!', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('If', 'O', 'O'), ('you', 'O', 'O'), ('go', 'O', 'O'), ('later', 'O', 'O'), (',', 'O', 'O'), ('it', 'O', 'O'), ("'s", 'O', 'O'), ('all', 'O', 'O'), ('cleaned', 'O', 'O'), ('up', 'O', 'O'), ('.', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('I', 'O', 'O'), ('have', 'O', 'O'), ('been', 'O', 'O'), ('to', 'O', 'O'), ('Kim', 'O', 'O'), ('at', 'O', 'O'), ('Cheveux', 'O', 'O'), ('for', 'O', 'O'), ('more', 'O', 'O'), ('than', 'O', 'O'), ('five', 'O', 'O'), ('years', 'O', 'O'), ('.', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [('Their', 'O', 'O'), ('service', 'O', 'O'), ('sucks', 'O', 'O'), ('to', 'O', 'O'), ('start', 'O', 'O'), ('off', 'O', 'O'), ('with', 'O', 'O'), (',', 'O', 'O'), ('people', 'O', 'O'), ('are', 'O', 'O'), ('cruel', 'O', 'O'), ('and', 'O', 'O'), ('ignorant', 'O', 'O'), ('.', 'O', 'O')]
# 1
# 1
# 1
# TEST 1 [('Natasha', 'O', 'O')]
# 7
# 7
# 7
# TEST 7 [('WELSH', 'O', 'O'), ('DRAGON', 'O', 'O'), ('FOUND', 'O', 'O'), (':', 'O', 'O'), ('URL', 'O', 'O'), ('via', 'O', 'O'), ('@USER', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [('Maybe', 'O', 'O'), ('he', 'O', 'O'), ('did', 'O', 'O'), ("n't", 'O', 'O'), ('do', 'O', 'O'), ('a', 'O', 'O'), ('good', 'O', 'O'), ('job', 'O', 'O'), ('and', 'O', 'O'), ('they', 'O', 'O'), ('told', 'O', 'O'), ('him', 'O', 'O'), ('so', 'O', 'O'), ('.', 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('She', 'O', 'O'), ('answers', 'O', 'O'), ('all', 'O', 'O'), ('questions', 'O', 'O'), ('asked', 'O', 'O'), ('and', 'O', 'O'), ('provides', 'O', 'O'), ('the', 'O', 'O'), ('best', 'O', 'O'), ('service', 'O', 'O'), ('i', 'O', 'O'), ('have', 'O', 'O'), ('ever', 'O', 'O'), ('seen', 'O', 'O'), ('.', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [('Once', 'O', 'O'), ('again', 'O', 'O'), (',', 'O', 'O'), ('I', 'O', 'O'), ('waited', 'O', 'O'), ('for', 'O', 'O'), ('quite', 'O', 'O'), ('a', 'O', 'O'), ('bit', 'O', 'O'), ('before', 'O', 'O'), ('being', 'O', 'O'), ('attended', 'O', 'O'), ('to', 'O', 'O'), ('.', 'O', 'O')]
# 16
# 16
# 16
# TEST 16 [('I', 'O', 'O'), ('was', 'O', 'O'), ('told', 'O', 'O'), ('to', 'O', 'O'), ('take', 'O', 'O'), ('my', 'O', 'O'), ('coffee', 'O', 'O'), ('to', 'O', 'O'), ('go', 'O', 'O'), ('if', 'O', 'O'), ('I', 'O', 'O'), ('wanted', 'O', 'O'), ('to', 'O', 'O'), ('finish', 'O', 'O'), ('it', 'O', 'O'), ('.', 'O', 'O')]
# 31
# 31
# 31
# TEST 31 [('I', 'O', 'O'), ('must', 'O', 'O'), ('say', 'O', 'O'), (',', 'O', 'O'), ('I', 'O', 'O'), ('was', 'O', 'O'), ('impressed', 'O', 'O'), ('with', 'O', 'O'), ('the', 'O', 'O'), ('size', 'O', 'O'), ('of', 'O', 'O'), ('the', 'O', 'O'), ('bar', 'O', 'O'), ('area', 'O', 'O'), ('and', 'O', 'O'), ('lounge', 'O', 'O'), (',', 'O', 'O'), ('&', 'O', 'O'), ('I', 'O', 'O'), ('liked', 'O', 'O'), ('that', 'O', 'O'), ('you', 'O', 'O'), ('could', 'O', 'O'), ('see', 'O', 'O'), ('the', 'O', 'O'), ('brewery', 'O', 'O'), ('right', 'O', 'O'), ('thru', 'O', 'O'), ('the', 'O', 'O'), ('glass', 'O', 'O'), ('!', 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('We', 'O', 'O'), ('really', 'O', 'O'), ('enjoyed', 'O', 'O'), ('our', 'O', 'O'), ('stay', 'O', 'O'), ('and', 'O', 'O'), ('would', 'O', 'O'), ('definitely', 'O', 'O'), ('stay', 'O', 'O'), ('at', 'O', 'O'), ('the', 'O', 'O'), ('Vintage', 'O', 'O'), ('Hostel', 'O', 'O'), ('again', 'O', 'O'), ('.', 'O', 'O')]
# 34
# 34
# 34
# TEST 34 [('RT', 'O', 'O'), ('@JANKYJ818', 'O', 'O'), (':', 'O', 'O'), ('Shout', 'O', 'O'), ('out', 'O', 'O'), ('2', 'O', 'O'), ('all', 'O', 'O'), ('the', 'O', 'O'), ('real', 'O', 'O'), ('women', 'O', 'O'), ('that', 'O', 'O'), ('hold', 'O', 'O'), ('they', 'O', 'O'), ('man', 'O', 'O'), ('down', 'O', 'O'), ('when', 'O', 'O'), ('he', 'O', 'O'), ("'s", 'O', 'O'), ('doin', 'O', 'O'), ('what', 'O', 'O'), ('he', 'O', 'O'), ('has', 'O', 'O'), ('2', 'O', 'O'), ('do', 'O', 'O'), ('2', 'O', 'O'), ('make', 'O', 'O'), ('it', 'O', 'O'), ('in', 'O', 'O'), ('this', 'O', 'O'), ('world', 'O', 'O'), ('!', 'O', 'O'), ('RESPECT', 'O', 'O'), ('T', 'O', 'O'), ('...', 'O', 'O')]
# 3
# 3
# 3
# TEST 3 [('Cute', 'O', 'O'), ('place', 'O', 'O'), ('also', 'O', 'O')]
# 9
# 9
# 9
# TEST 9 [('Cathy', 'O', 'O'), ('******', 'O', 'O'), ('Five', 'O', 'O'), ('Stars', 'O', 'O'), ('for', 'O', 'O'), ('Lake', 'O', 'O'), ('Forest', 'O', 'O'), ('Tots', 'O', 'O'), ('.', 'O', 'O')]
# 25
# 25
# 25
# TEST 25 [('I', 'O', 'O'), ('miss', 'O', 'O'), ('being', 'O', 'O'), ('able', 'O', 'O'), ('to', 'O', 'O'), ('run', 'O', 'O'), ('and', 'O', 'O'), ('dance', 'O', 'O'), ('around', 'O', 'O'), ('all', 'O', 'O'), ('day', 'O', 'O'), ('instead', 'O', 'O'), ('of', 'O', 'O'), ('having', 'O', 'O'), ('to', 'O', 'O'), ('catch', 'O', 'O'), ('my', 'O', 'O'), ('breath', 'O', 'O'), ('every', 'O', 'O'), ('five', 'O', 'O'), ('minutes', 'O', 'O'), ('of', 'O', 'O'), ('my', 'O', 'O'), ('life', 'O', 'O'), ('.', 'O', 'O')]
# 26
# 26
# 26
# TEST 26 [('Do', 'O', 'O'), ("n't", 'O', 'O'), ('go', 'O', 'O'), ('here', 'O', 'O'), ('unless', 'O', 'O'), ('you', 'O', 'O'), ('want', 'O', 'O'), ('to', 'O', 'O'), ('sit', 'O', 'O'), (',', 'O', 'O'), ('order', 'O', 'O'), (',', 'O', 'O'), ('eat', 'O', 'O'), ('and', 'O', 'O'), ('be', 'O', 'O'), ('asked', 'O', 'O'), ('to', 'O', 'O'), ('leave', 'O', 'O'), ('all', 'O', 'O'), ('in', 'O', 'O'), ('a', 'O', 'O'), ('matter', 'O', 'O'), ('of', 'O', 'O'), ('20', 'O', 'O'), ('minutes', 'O', 'O'), ('.', 'O', 'O')]
# 2
# 2
# 2
# TEST 2 [('Never', 'O', 'O'), ('again', 'O', 'O')]
# 22
# 22
# 22
# TEST 22 [('Once', 'O', 'O'), ('they', 'O', 'O'), ('fixed', 'O', 'O'), ('it', 'O', 'O'), ('they', 'O', 'O'), ('answetred', 'O', 'O'), ('all', 'O', 'O'), ('of', 'O', 'O'), ('my', 'O', 'O'), ('questions', 'O', 'O'), ('with', 'O', 'O'), ('no', 'O', 'O'), ('hesitations', 'O', 'O'), ('and', 'O', 'O'), ('then', 'O', 'O'), ('gave', 'O', 'O'), ('me', 'O', 'O'), ('the', 'O', 'O'), ('best', 'O', 'O'), ('quote', 'O', 'O'), ('ever', 'O', 'O'), ('.', 'O', 'O')]
# 9
# 9
# 9
# TEST 9 [('This', 'O', 'O'), ('was', 'O', 'O'), ('nothing', 'O', 'O'), ('like', 'O', 'O'), ('New', 'O', 'O'), ('York', 'O', 'O'), ('style', 'O', 'O'), ('pizza', 'O', 'O'), ('!!!.', 'O', 'O')]
# 9
# 9
# 9
# TEST 9 [('Photo', 'O', 'O'), (':', 'O', 'O'), ('SHE', 'O', 'O'), ('GETS', 'O', 'O'), ('TIRED', 'O', 'O'), ('AFTER', 'O', 'O'), ('SEX', 'O', 'O'), ('!', 'O', 'O'), ('http://tumblr.com/xsu17j0ynx', 'O', 'O')]
# 8
# 8
# 8
# TEST 8 [('I', 'O', 'O'), ('had', 'O', 'O'), ('no', 'O', 'O'), ('problem', 'O', 'O'), ('with', 'O', 'O'), ('my', 'O', 'O'), ('delivery', 'O', 'O'), ('.', 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('Bday', 'O', 'O'), ('party', 'O', 'O'), ('for', 'O', 'O'), ('@SILVRSCREENSTAR', 'O', 'O'), ('then', 'O', 'O'), ('hp6', 'O', 'O'), ('with', 'O', 'O'), ('my', 'O', 'O'), ('girls', 'O', 'O'), ('to', 'O', 'O'), ('get', 'O', 'O'), ('ready', 'O', 'O'), ('for', 'O', 'O'), ('Sunday', 'O', 'O'), ('!!', 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('@Yeweezii', 'O', 'O'), ('Jst', 'O', 'O'), ('lock', 'O', 'O'), ('her', 'O', 'O'), ('outside', 'O', 'O'), ('4', 'O', 'O'), ('d', 'O', 'O'), ('nite', 'O', 'O'), ('.', 'O', 'O'), ('It', 'O', 'O'), ('workz', 'O', 'O'), ('al', 'O', 'O'), ('d', 'O', 'O'), ('time', 'O', 'O'), (':-D', 'O', 'O')]
# 8
# 8
# 8
# TEST 8 [('The', 'O', 'O'), ('entire', 'O', 'O'), ('negotiation', 'O', 'O'), ('took', 'O', 'O'), ('about', 'O', 'O'), ('20', 'O', 'O'), ('minutes', 'O', 'O'), ('.', 'O', 'O')]
# 16
# 16
# 16
# TEST 16 [('TEXAS', 'O', 'O'), ('ROADHOUSE', 'O', 'O'), ('HAS', 'O', 'O'), ('VERY', 'O', 'O'), ('GOOD', 'O', 'O'), ('MEALS', 'O', 'O'), (',', 'O', 'O'), ('THAT', 'O', 'O'), ('THE', 'O', 'O'), ('MEAT', 'O', 'O'), ('COMES', 'O', 'O'), ('RIGHT', 'O', 'O'), ('OFF', 'O', 'O'), ('THE', 'O', 'O'), ('BONES', 'O', 'O'), ('.', 'O', 'O')]
# 10
# 10
# 10
# TEST 10 [('Same', 'O', 'O'), ('clerk', 'O', 'O'), ('had', 'O', 'O'), ('considerable', 'O', 'O'), ('difficulty', 'O', 'O'), ('taking', 'O', 'O'), ('down', 'O', 'O'), ('a', 'O', 'O'), ('number', 'O', 'O'), ('.', 'O', 'O')]
# 33
# 33
# 33
# TEST 33 [('Firstly', 'O', 'O'), (',', 'O', 'O'), ('the', 'O', 'O'), ('other', 'O', 'O'), ('reviewer', 'O', 'O'), ('clearly', 'O', 'O'), ('has', 'O', 'O'), ('never', 'O', 'O'), ('been', 'O', 'O'), ('to', 'O', 'O'), ('Nick', 'O', 'O'), ("'s", 'O', 'O'), (',', 'O', 'O'), ('or', 'O', 'O'), ('he', 'O', 'O'), ('would', 'O', 'O'), ('know', 'O', 'O'), ('that', 'O', 'O'), ('Nick', 'O', 'O'), ('only', 'O', 'O'), ('charges', 'O', 'O'), ('$', 'O', 'O'), ('13', 'O', 'O'), ('for', 'O', 'O'), ('a', 'O', 'O'), ('haircut', 'O', 'O'), ('which', 'O', 'O'), ('is', 'O', 'O'), ('pretty', 'O', 'O'), ('much', 'O', 'O'), ('industry', 'O', 'O'), ('standard', 'O', 'O'), ('.', 'O', 'O')]
# 18
# 18
# 18
# TEST 18 [('It', 'O', 'O'), ('is', 'O', 'O'), ('all', 'O', 'O'), ('very', 'O', 'O'), ('unique', 'O', 'O'), ('and', 'O', 'O'), ('you', 'O', 'O'), ('wo', 'O', 'O'), ('nt', 'O', 'O'), ('find', 'O', 'O'), ('any', 'O', 'O'), ('other', 'O', 'O'), ('baby', 'O', 'O'), ('wearing', 'O', 'O'), ('the', 'O', 'O'), ('same', 'O', 'O'), ('stuff', 'O', 'O'), ('.', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('Now', 'O', 'O'), ('I', 'O', 'O'), ("'m", 'O', 'O'), ('able', 'O', 'O'), ('to', 'O', 'O'), ('play', 'O', 'O'), ('the', 'O', 'O'), ('piano', 'O', 'O'), ('pretty', 'O', 'O'), ('well', 'O', 'O'), ('.', 'O', 'O')]
# 17
# 17
# 17
# TEST 17 [('I', 'O', 'O'), ('v', 'O', 'O'), ('just', 'O', 'O'), ('had', 'O', 'O'), ('my', 'O', 'O'), ('bmw', 'O', 'O'), ('z3', 'O', 'O'), ('rear', 'O', 'O'), ('window', 'O', 'O'), ('replaced', 'O', 'O'), ('by', 'O', 'O'), ('the', 'O', 'O'), ('guys', 'O', 'O'), ('at', 'O', 'O'), ('kelvin', 'O', 'O'), ('trimmers', 'O', 'O'), ('.', 'O', 'O')]
# 38
# 38
# 38
# TEST 38 [('If', 'O', 'O'), ('you', 'O', 'O'), ('are', 'O', 'O'), ('in', 'O', 'O'), ('town', 'O', 'O'), ('and', 'O', 'O'), ('need', 'O', 'O'), ('that', 'O', 'O'), ('kind', 'O', 'O'), ('of', 'O', 'O'), ('space', 'O', 'O'), ('I', 'O', 'O'), ('say', 'O', 'O'), ('stay', 'O', 'O'), ('here', 'O', 'O'), ('but', 'O', 'O'), ('if', 'O', 'O'), ('you', 'O', 'O'), ('are', 'O', 'O'), ('looking', 'O', 'O'), ('for', 'O', 'O'), ('a', 'O', 'O'), ('little', 'O', 'O'), ('more', 'O', 'O'), ('upscale', 'O', 'O'), ('affair', 'O', 'O'), ('do', 'O', 'O'), ("n't", 'O', 'O'), ('let', 'O', 'O'), ('the', 'O', 'O'), ('pictures', 'O', 'O'), ('fool', 'O', 'O'), ('you', 'O', 'O'), ('and', 'O', 'O'), ('book', 'O', 'O'), ('somewhere', 'O', 'O'), ('else', 'O', 'O'), ('.', 'O', 'O')]
# 17
# 17
# 17
# TEST 17 [('Actually', 'O', 'O'), ('working', 'O', 'O'), ('out', 'O', 'O'), ('there', 'O', 'O'), ('was', 'O', 'O'), ('good', 'O', 'O'), ('-', 'O', 'O'), ('the', 'O', 'O'), ('machines', 'O', 'O'), ('are', 'O', 'O'), ('nice', 'O', 'O'), ('and', 'O', 'O'), ('the', 'O', 'O'), ('classes', 'O', 'O'), ('are', 'O', 'O'), ('fun', 'O', 'O'), ('.', 'O', 'O')]
# 12
# 12
# 12
# TEST 12 [('He', 'O', 'O'), ('responded', 'O', 'O'), ('"', 'O', 'O'), ('we', 'O', 'O'), ('have', 'O', 'O'), ('problem', 'O', 'O'), ('with', 'O', 'O'), ("'", 'O', 'O'), ('people', 'O', 'O'), ("'", 'O', 'O'), ('"', 'O', 'O'), ('.', 'O', 'O')]
# 22
# 22
# 22
# TEST 22 [('There', 'O', 'O'), ('are', 'O', 'O'), ('some', 'O', 'O'), ('constraints', 'O', 'O'), ('as', 'O', 'O'), ('to', 'O', 'O'), ('how', 'O', 'O'), ('high', 'O', 'O'), ('or', 'O', 'O'), ('how', 'O', 'O'), ('low', 'O', 'O'), ('you', 'O', 'O'), ('can', 'O', 'O'), ('set', 'O', 'O'), ('your', 'O', 'O'), ('price', 'O', 'O'), ('when', 'O', 'O'), ('posting', 'O', 'O'), ('your', 'O', 'O'), ('bid', 'O', 'O'), ('.', 'O', 'O'), ('URL', 'O', 'O')]
# 10
# 10
# 10
# TEST 10 [('Thanks', 'O', 'O'), ('for', 'O', 'O'), ('the', 'O', 'O'), ('great', 'O', 'O'), ('deal', 'O', 'O'), ('and', 'O', 'O'), ('the', 'O', 'O'), ('great', 'O', 'O'), ('car', 'O', 'O'), ('!', 'O', 'O')]
# 23
# 23
# 23
# TEST 23 [('yayi', 'O', 'O'), ('dont', 'O', 'O'), ('think', 'O', 'O'), ('today', 'O', 'O'), ('can', 'O', 'O'), ('get', 'O', 'O'), ('any', 'O', 'O'), ('better', 'O', 'O'), ('@planetjedward', 'O', 'O'), ('and', 'O', 'O'), ('@thewantedmusic', 'O', 'O'), ('on', 'O', 'O'), ('my', 'O', 'O'), ('tv', 'O', 'O'), (':)', 'O', 'O'), ('aka', 'O', 'O'), ('derek', 'O', 'O'), ('[', 'O', 'O'), ('Like', 'O', 'O'), ('it', 'O', 'O'), ('?', 'O', 'O'), ('http://bit.ly/9U3nrK', 'O', 'O'), (']', 'O', 'O')]
# 8
# 8
# 8
# TEST 8 [('I', 'O', 'O'), ('like', 'O', 'O'), ('@SouljaBoy', 'O', 'O'), ('songs', 'O', 'O'), ('after', 'O', 'O'), ('a', 'O', 'O'), ('few', 'O', 'O'), ('drinks', 'O', 'O')]
# 28
# 28
# 28
# TEST 28 [('Just', 'O', 'O'), ('found', 'O', 'O'), ('out', 'O', 'O'), ('my', 'O', 'O'), ('custom', 'O', 'O'), ('@SteveCorino', 'O', 'O'), ('shirt', 'O', 'O'), ('wo', 'O', 'O'), ("n't", 'O', 'O'), ('arrive', 'O', 'O'), ('in', 'O', 'O'), ('time', 'O', 'O'), ('for', 'O', 'O'), ('next', 'O', 'O'), ('weekend', 'O', 'O'), ("'s", 'O', 'O'), ('ROH', 'O', 'O'), ('shows', 'O', 'O'), ('.', 'O', 'O'), ('How', 'O', 'O'), ('am', 'O', 'O'), ('I', 'O', 'O'), ('gonna', 'O', 'O'), ('rep', 'O', 'O'), ('old', 'O', 'O'), ('school', 'O', 'O'), ('now', 'O', 'O'), ('?', 'O', 'O')]
# 4
# 4
# 4
# TEST 4 [('Will', 'O', 'O'), ('look', 'O', 'O'), ('beautiful', 'O', 'O'), ('.', 'O', 'O')]
# 19
# 19
# 19
# TEST 19 [('The', 'O', 'O'), ('ability', 'O', 'O'), ('to', 'O', 'O'), ('smile', 'O', 'O'), ('and', 'O', 'O'), ('eat', 'O', 'O'), ('again', 'O', 'O'), ('can', 'O', 'O'), ('only', 'O', 'O'), ('be', 'O', 'O'), ('described', 'O', 'O'), ('as', 'O', 'O'), ('a', 'O', 'O'), ('whole', 'O', 'O'), ('new', 'O', 'O'), ('lease', 'O', 'O'), ('on', 'O', 'O'), ('life', 'O', 'O'), ('.', 'O', 'O')]
# 18
# 18
# 18
# TEST 18 [('I', 'O', 'O'), ('am', 'O', 'O'), ('a', 'O', 'O'), ('business', 'O', 'O'), ('owner', 'O', 'O'), ('in', 'O', 'O'), ('downtown', 'O', 'O'), ('Saratoga', 'O', 'O'), ('Springs', 'O', 'O'), ('and', 'O', 'O'), ('wish', 'O', 'O'), ('this', 'O', 'O'), ('restaurant', 'O', 'O'), ('was', 'O', 'O'), ('in', 'O', 'O'), ('our', 'O', 'O'), ('town', 'O', 'O'), ('!', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [("I'm", 'O', 'O'), ('sharing', 'O', 'O'), ('my', 'O', 'O'), ('favorite', 'O', 'O'), ('blueberry', 'O', 'O'), ('muffin', 'O', 'O'), ('recipe', 'O', 'O'), ('today', 'O', 'O'), ('.', 'O', 'O'), ('URL', 'O', 'O'), ('URL', 'O', 'O')]
# 8
# 8
# 8
# TEST 8 [('LIVESTRONG', 'O', 'O'), ('Day', 'O', 'O'), ('is', 'O', 'O'), ('10-02-10', 'O', 'O'), ('around', 'O', 'O'), ('the', 'O', 'O'), ('world', 'O', 'O'), ('.', 'O', 'O')]
# 34
# 34
# 34
# TEST 34 [('The', 'O', 'O'), ('staff', 'O', 'O'), ('was', 'O', 'O'), ('friendly', 'O', 'O'), (',', 'O', 'O'), ('especially', 'O', 'O'), ('the', 'O', 'O'), ('front', 'O', 'O'), ('desk', 'O', 'O'), ('female', 'O', 'O'), ('supervisor', 'O', 'O'), (',', 'O', 'O'), ('and', 'O', 'O'), ('seemed', 'O', 'O'), ('to', 'O', 'O'), ('want', 'O', 'O'), ('to', 'O', 'O'), ('help', 'O', 'O'), (',', 'O', 'O'), ('but', 'O', 'O'), ('too', 'O', 'O'), ('many', 'O', 'O'), ('unusual', 'O', 'O'), ('things', 'O', 'O'), ('happened', 'O', 'O'), ('to', 'O', 'O'), ('make', 'O', 'O'), ('us', 'O', 'O'), ('want', 'O', 'O'), ('to', 'O', 'O'), ('stay', 'O', 'O'), ('there', 'O', 'O'), ('again', 'O', 'O'), ('.', 'O', 'O')]
# 29
# 29
# 29
# TEST 29 [('We', 'O', 'O'), ('took', 'O', 'O'), ('our', 'O', 'O'), ('7', 'O', 'O'), ('month', 'O', 'O'), ('old', 'O', 'O'), ('and', 'O', 'O'), ('she', 'O', 'O'), ('laughed', 'O', 'O'), ('and', 'O', 'O'), ('giggled', 'O', 'O'), ('when', 'O', 'O'), ('(', 'O', 'O'), ('very', 'O', 'O'), ('harshly', 'O', 'O'), ('I', 'O', 'O'), ('might', 'O', 'O'), ('add', 'O', 'O'), (')', 'O', 'O'), ('grabbing', 'O', 'O'), ('and', 'O', 'O'), ("'", 'O', 'O'), ('kissed', 'O', 'O'), ("'", 'O', 'O'), ('the', 'O', 'O'), ('goats', 'O', 'O'), ('and', 'O', 'O'), ('lambs', 'O', 'O'), ('.', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('NEW', 'O', 'O'), ('POST', 'O', 'O'), (':', 'O', 'O'), ('More', 'O', 'O'), ('than', 'O', 'O'), ('NUMBER', 'O', 'O'), ('vintage', 'O', 'O'), ('ads', 'O', 'O'), ('at', 'O', 'O'), ('your', 'O', 'O'), ('fingertips', 'O', 'O'), ('URL', 'O', 'O'), ('#vintage', 'O', 'O')]
# 6
# 6
# 6
# TEST 6 [('Good', 'O', 'O'), (',', 'O', 'O'), ('friendly', 'O', 'O'), (',', 'O', 'O'), ('reasonable', 'O', 'O'), ('service', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('I', 'O', 'O'), ('found', 'O', 'O'), ('them', 'O', 'O'), ('extremely', 'O', 'O'), ('professional', 'O', 'O'), ('and', 'O', 'O'), ('would', 'O', 'O'), ('highly', 'O', 'O'), ('recommend', 'O', 'O'), ('them', 'O', 'O'), ('.', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [('The', 'O', 'O'), ('other', 'O', 'O'), ('rolls', 'O', 'O'), ('were', 'O', 'O'), ("n't", 'O', 'O'), ('at', 'O', 'O'), ('all', 'O', 'O'), ('special', 'O', 'O'), (',', 'O', 'O'), ('especially', 'O', 'O'), ('given', 'O', 'O'), ('their', 'O', 'O'), ('pricing', 'O', 'O'), ('.', 'O', 'O')]
# 1
# 1
# 1
# TEST 1 [('http://www.speedtest.net/result/1155244347.png', 'O', 'O')]
# 6
# 6
# 6
# TEST 6 [('Their', 'O', 'O'), ('customer', 'O', 'O'), ('service', 'O', 'O'), ('was', 'O', 'O'), ('perfect', 'O', 'O'), ('!', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('Do', 'O', 'O'), ('your', 'O', 'O'), ('self', 'O', 'O'), ('a', 'O', 'O'), ('favor', 'O', 'O'), ('and', 'O', 'O'), ('do', 'O', 'O'), ('not', 'O', 'O'), ('go', 'O', 'O'), ('to', 'O', 'O'), ('this', 'O', 'O'), ('establishment', 'O', 'O'), ('.', 'O', 'O')]
# 4
# 4
# 4
# TEST 4 [('Definitely', 'O', 'O'), ('a', 'O', 'O'), ('must', 'O', 'O'), ('.', 'O', 'O')]
# 9
# 9
# 9
# TEST 9 [('Very', 'O', 'O'), ('friendly', 'O', 'O'), ('and', 'O', 'O'), ('ALWAY', 'O', 'O'), ('contactable', 'O', 'O'), ('even', 'O', 'O'), ('at', 'O', 'O'), ('weekends', 'O', 'O'), ('.', 'O', 'O')]
# 10
# 10
# 10
# TEST 10 [('We', 'O', 'O'), ('have', 'O', 'O'), ('stayed', 'O', 'O'), ('at', 'O', 'O'), ('Tanglewood', 'O', 'O'), ('for', 'O', 'O'), ('many', 'O', 'O'), ('years', 'O', 'O'), ('now', 'O', 'O'), ('.', 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('RT', 'O', 'O'), ('@mhking', 'O', 'O'), (':', 'O', 'O'), ('Memphis', 'O', 'O'), ('man', 'O', 'O'), ('shoots', 'O', 'O'), ('teen', 'O', 'O'), ('who', 'O', 'O'), ('refuses', 'O', 'O'), ('to', 'O', 'O'), ('pull', 'O', 'O'), ('up', 'O', 'O'), ('saggy', 'O', 'O'), ('pants', 'O', 'O'), ('http://t.co/wZ0LIUw', 'O', 'O')]
# 6
# 6
# 6
# TEST 6 [('DO', 'O', 'O'), ('NOT', 'O', 'O'), ('USE', 'O', 'O'), ('THIS', 'O', 'O'), ('COMPANY', 'O', 'O'), ('.', 'O', 'O')]
# 26
# 26
# 26
# TEST 26 [('My', 'O', 'O'), ('dad', 'O', 'O'), ('laughed', 'O', 'O'), ('when', 'O', 'O'), ('he', 'O', 'O'), ('read', 'O', 'O'), ('about', 'O', 'O'), ('Linkin', 'O', 'O'), ('Park', 'O', 'O'), ('being', 'O', 'O'), ('classified', 'O', 'O'), ('under', 'O', 'O'), ("'", 'O', 'O'), ("rap-rock'.", 'O', 'O'), ('I', 'O', 'O'), ('hope', 'O', 'O'), ('he', 'O', 'O'), ('did', 'O', 'O'), ("n't", 'O', 'O'), ('mean', 'O', 'O'), ("'", 'O', 'O'), ('shit', 'O', 'O'), ('my', 'O', 'O'), ('son', 'O', 'O'), ('listens', 'O', 'O'), ("to'.", 'O', 'O')]
# 15
# 15
# 15
# TEST 15 [('They', 'O', 'O'), ('still', 'O', 'O'), ('would', 'O', 'O'), ('not', 'O', 'O'), ('drive', 'O', 'O'), ('the', 'O', 'O'), ('car', 'O', 'O'), ('with', 'O', 'O'), ('me', 'O', 'O'), ('to', 'O', 'O'), ('show', 'O', 'O'), ('their', 'O', 'O'), ('mpg', 'O', 'O'), ('number', 'O', 'O'), ('.', 'O', 'O')]
# 14
# 14
# 14
# TEST 14 [('This', 'O', 'O'), ('is', 'O', 'O'), ('by', 'O', 'O'), ('far', 'O', 'O'), ('the', 'O', 'O'), ('BEST', 'O', 'O'), ('B&B', 'O', 'O'), ('that', 'O', 'O'), ('we', 'O', 'O'), ('have', 'O', 'O'), ('ever', 'O', 'O'), ('stayed', 'O', 'O'), ('at', 'O', 'O'), ('!', 'O', 'O')]
# 5
# 5
# 5
# TEST 5 [('Do', 'O', 'O'), ('not', 'O', 'O'), ('trust', 'O', 'O'), ('them', 'O', 'O'), ('!', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('The', 'O', 'O'), ('staff', 'O', 'O'), ('is', 'O', 'O'), ('also', 'O', 'O'), ('just', 'O', 'O'), ('so', 'O', 'O'), ('pleasant', 'O', 'O'), ('to', 'O', 'O'), ('deal', 'O', 'O'), ('with', 'O', 'O'), ('.', 'O', 'O')]
# 7
# 7
# 7
# TEST 7 [('Scheduled', 'O', 'O'), ('appointment', 'O', 'O'), ('for', 'O', 'O'), ('8:30', 'O', 'O'), ('Monday', 'O', 'O'), ('morning', 'O', 'O'), ('.', 'O', 'O')]
# 6
# 6
# 6
# TEST 6 [('It', 'O', 'O'), ('was', 'O', 'O'), ("n't", 'O', 'O'), ('completly', 'O', 'O'), ('impossible', 'O', 'O'), ('!!!!', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('Nothing', 'O', 'O'), ('wrong', 'O', 'O'), ('with', 'O', 'O'), ('it', 'O', 'O'), (',', 'O', 'O'), ('just', 'O', 'O'), ('better', 'O', 'O'), ('options', 'O', 'O'), ('at', 'O', 'O'), ('this', 'O', 'O'), ('price', 'O', 'O'), ('point', 'O', 'O'), ('.', 'O', 'O')]
# 21
# 21
# 21
# TEST 21 [('So', 'O', 'O'), ('I', 'O', 'O'), ('really', 'O', 'O'), ('felt', 'O', 'O'), ('like', 'O', 'O'), ('this', 'O', 'O'), ('place', 'O', 'O'), ('was', 'O', 'O'), ('extremely', 'O', 'O'), ('outdated', 'O', 'O'), ('especially', 'O', 'O'), ('since', 'O', 'O'), ('the', 'O', 'O'), ('pictures', 'O', 'O'), ('make', 'O', 'O'), ('it', 'O', 'O'), ('look', 'O', 'O'), ('nice', 'O', 'O'), ('and', 'O', 'O'), ('modern', 'O', 'O'), ('.', 'O', 'O')]
# 26
# 26
# 26
# TEST 26 [('The', 'O', 'O'), ('poor', 'O', 'O'), ('quality', 'O', 'O'), ('starts', 'O', 'O'), ('at', 'O', 'O'), ('the', 'O', 'O'), ('receptionist', 'O', 'O'), ('desk', 'O', 'O'), (',', 'O', 'O'), ('where', 'O', 'O'), ('the', 'O', 'O'), ('staff', 'O', 'O'), ('is', 'O', 'O'), ('very', 'O', 'O'), ('impatient', 'O', 'O'), ('and', 'O', 'O'), ('lack', 'O', 'O'), ('the', 'O', 'O'), ('efficiency', 'O', 'O'), ('I', 'O', 'O'), ('once', 'O', 'O'), ('loved', 'O', 'O'), ('about', 'O', 'O'), ('the', 'O', 'O'), ('office', 'O', 'O'), ('.', 'O', 'O')]
# 25
# 25
# 25
# TEST 25 [('If', 'O', 'O'), ('you', 'O', 'O'), ('are', 'O', 'O'), ('staying', 'O', 'O'), ('in', 'O', 'O'), ('Gainesville', 'O', 'O'), (',', 'O', 'O'), ('come', 'O', 'O'), ('check', 'O', 'O'), ('out', 'O', 'O'), ('Costa', 'O', 'O'), ('Lounge', 'O', 'O'), ('TONIGHT', 'O', 'O'), ('!', 'O', 'O'), ('Say', 'O', 'O'), ('you', 'O', 'O'), ('are', 'O', 'O'), ('with', 'O', 'O'), ('salsa', 'O', 'O'), ('caliente', 'O', 'O'), ('and', 'O', 'O'), ('get', 'O', 'O'), ('in', 'O', 'O'), ('...', 'O', 'O'), ('http://fb.me/FZVzm8H9', 'O', 'O')]
# 18
# 18
# 18
# TEST 18 [('they', 'O', 'O'), ('seemed', 'O', 'O'), ('more', 'O', 'O'), ('interested', 'O', 'O'), ('in', 'O', 'O'), ('helping', 'O', 'O'), ('me', 'O', 'O'), ('find', 'O', 'O'), ('the', 'O', 'O'), ('right', 'O', 'O'), ('car', 'O', 'O'), ('rather', 'O', 'O'), ('then', 'O', 'O'), ('just', 'O', 'O'), ('make', 'O', 'O'), ('a', 'O', 'O'), ('sale', 'O', 'O'), ('.', 'O', 'O')]
# 10
# 10
# 10
# TEST 10 [('Here', 'O', 'O'), ('I', 'O', 'O'), ('am', 'O', 'O'), ('now', 'O', 'O'), ('driving', 'O', 'O'), ('confidently', 'O', 'O'), ('on', 'O', 'O'), ('my', 'O', 'O'), ('own', 'O', 'O'), ('.', 'O', 'O')]
# 34
# 34
# 34
# TEST 34 [('I', 'O', 'O'), ('will', 'O', 'O'), ('never', 'O', 'O'), ('go', 'O', 'O'), ('back', 'O', 'O'), ('to', 'O', 'O'), ('this', 'O', 'O'), ('place', 'O', 'O'), ('and', 'O', 'O'), ('I', 'O', 'O'), ('am', 'O', 'O'), ('reporting', 'O', 'O'), ('them', 'O', 'O'), ('to', 'O', 'O'), ('the', 'O', 'O'), ('better', 'O', 'O'), ('business', 'O', 'O'), ('bureau', 'O', 'O'), ('for', 'O', 'O'), ('such', 'O', 'O'), ('horrible', 'O', 'O'), ('customer', 'O', 'O'), ('relations', 'O', 'O'), ('and', 'O', 'O'), ('basically', 'O', 'O'), ('sabotaging', 'O', 'O'), ('my', 'O', 'O'), ('pizza', 'O', 'O'), ('and', 'O', 'O'), ('taking', 'O', 'O'), ('my', 'O', 'O'), ('$', 'O', 'O'), ('25', 'O', 'O'), ('.', 'O', 'O')]
# 4
# 4
# 4
# TEST 4 [('Do', 'O', 'O'), ("n't", 'O', 'O'), ('go', 'O', 'O'), ('!', 'O', 'O')]
# 1
# 1
# 1
# TEST 1 [('OMFG', 'O', 'O')]
# 34
# 34
# 34
# TEST 34 [('The', 'O', 'O'), ('second', 'O', 'O'), ('vendor', 'O', 'O'), ('charged', 'O', 'O'), ('$', 'O', 'O'), ('55', 'O', 'O'), ('(', 'O', 'O'), ('less', 'O', 'O'), ('than', 'O', 'O'), ('half', 'O', 'O'), ('of', 'O', 'O'), ('what', 'O', 'O'), ('A&E', 'O', 'O'), ('charges', 'O', 'O'), (')', 'O', 'O'), ('to', 'O', 'O'), ('come', 'O', 'O'), ('and', 'O', 'O'), ('applied', 'O', 'O'), ('that', 'O', 'O'), ('to', 'O', 'O'), ('the', 'O', 'O'), ('price', 'O', 'O'), ('of', 'O', 'O'), ('the', 'O', 'O'), ('repair', 'O', 'O'), ('service', 'O', 'O'), ('(', 'O', 'O'), ('which', 'O', 'O'), ('A&E', 'O', 'O'), ('does', 'O', 'O'), ('not', 'O', 'O'), (')', 'O', 'O'), ('.', 'O', 'O')]
# 27
# 27
# 27
# TEST 27 [('Try', 'O', 'O'), ('the', 'O', 'O'), ('360', 'O', 'O'), ('restraunt', 'O', 'O'), ('u', 'O', 'O'), ('spin', 'O', 'O'), ('in', 'O', 'O'), ('the', 'O', 'O'), ('cn', 'O', 'O'), ('tower', 'O', 'O'), ('with', 'O', 'O'), ('a', 'O', 'O'), ('beautiful', 'O', 'O'), ('view', 'O', 'O'), ('the', 'O', 'O'), ('sky', 'O', 'O'), ('pod', 'O', 'O'), ('elevator', 'O', 'O'), ('is', 'O', 'O'), ('about', 'O', 'O'), ('an', 'O', 'O'), ('hour', 'O', 'O'), ('line', 'O', 'O'), ('up', 'O', 'O'), ('in', 'O', 'O'), ('the', 'O', 'O'), ('summer', 'O', 'O')]
# 2
# 2
# 2
# TEST 2 [('Avoid', 'O', 'O'), ('!', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('The', 'O', 'O'), ('owner', 'O', 'O'), (',', 'O', 'O'), ('Jean', 'O', 'O'), (',', 'O', 'O'), ('has', 'O', 'O'), ('been', 'O', 'O'), ('there', 'O', 'O'), ('31', 'O', 'O'), ('years', 'O', 'O'), ('!', 'O', 'O')]
# 22
# 22
# 22
# TEST 22 [('No', 'O', 'O'), ('I', 'O', 'O'), ("'m", 'O', 'O'), ('not', 'O', 'O'), ('saying', 'O', 'O'), ('I', 'O', 'O'), ("'m", 'O', 'O'), ('sorry', 'O', 'O'), ('One', 'O', 'O'), ('day', 'O', 'O'), (',', 'O', 'O'), ('maybe', 'O', 'O'), ("'ll", 'O', 'O'), ('meet', 'O', 'O'), ('again', 'O', 'O'), ('No', 'O', 'O'), ('No', 'O', 'O'), ('No', 'O', 'O'), ('No', 'O', 'O'), ('(', 'O', 'O'), ('8', 'O', 'O'), (')', 'O', 'O')]
# 23
# 23
# 23
# TEST 23 [('The', 'O', 'O'), ('Atmosphere', 'O', 'O'), ('is', 'O', 'O'), ('the', 'O', 'O'), ('best', 'O', 'O'), ('..', 'O', 'O'), ('Italian', 'O', 'O'), ('music', 'O', 'O'), (',', 'O', 'O'), ('candles', 'O', 'O'), (',', 'O', 'O'), ('helpful', 'O', 'O'), ('and', 'O', 'O'), ('friendly', 'O', 'O'), ('staff', 'O', 'O'), ('...', 'O', 'O'), ('And', 'O', 'O'), ('the', 'O', 'O'), ('food', 'O', 'O'), ('is', 'O', 'O'), ('beautiful', 'O', 'O'), ('too', 'O', 'O'), ('!', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('So', 'O', 'O'), ('Handy', 'O', 'O'), ('for', 'O', 'O'), ('Local', 'O', 'O'), ('La', 'O', 'O'), ('Jolla', 'O', 'O'), ('Stuff', 'O', 'O'), ('-', 'O', 'O'), ('Especially', 'O', 'O'), ('for', 'O', 'O'), ('Finding', 'O', 'O'), ('Residential', 'O', 'O'), ('Numbers', 'O', 'O')]
# 30
# 30
# 30
# TEST 30 [('HA', 'O', 'O'), ('!', 'O', 'O'), ('RT', 'O', 'O'), ('@ew32766', 'O', 'O'), ('I', 'O', 'O'), ('love', 'O', 'O'), ('it', 'O', 'O'), ('when', 'O', 'O'), ('my', 'O', 'O'), ('mom', 'O', 'O'), ('posts', 'O', 'O'), ('status', 'O', 'O'), ('updates', 'O', 'O'), ('on', 'O', 'O'), ('FB', 'O', 'O'), (',', 'O', 'O'), ('they', 'O', 'O'), ('are', 'O', 'O'), ('usually', 'O', 'O'), ('personal', 'O', 'O'), ('messages', 'O', 'O'), ('she', 'O', 'O'), ('meant', 'O', 'O'), ('2write', 'O', 'O'), ('on', 'O', 'O'), ('someone', 'O', 'O'), ("'s", 'O', 'O'), ('wall', 'O', 'O'), ('.', 'O', 'O'), (';)', 'O', 'O')]
# 5
# 5
# 5
# TEST 5 [('Love', 'O', 'O'), ('my', 'O', 'O'), ('home', 'O', 'O'), ('at', 'O', 'O'), ('Creekside', 'O', 'O')]
# 17
# 17
# 17
# ...
# 5
# 5
# 5
# TEST 5 [('Give', 'O', 'O'), ('them', 'O', 'O'), ('a', 'O', 'O'), ('try', 'O', 'O'), ('!', 'O', 'O')]
# 9
# 9
# 9
# TEST 9 [('I', 'O', 'O'), ('have', 'O', 'O'), ('been', 'O', 'O'), ('using', 'O', 'O'), ('Steele', 'O', 'O'), ('Electric', 'O', 'O'), ('for', 'O', 'O'), ('years', 'O', 'O'), ('.', 'O', 'O')]
# 17
# 17
# 17
# TEST 17 [('It', 'O', 'O'), ("'s", 'O', 'O'), ('the', 'O', 'O'), ('best', 'O', 'O'), ('meal', 'O', 'O'), ('for', 'O', 'O'), ('the', 'O', 'O'), ('money', 'O', 'O'), ('you', 'O', 'O'), ('will', 'O', 'O'), ('find', 'O', 'O'), ('in', 'O', 'O'), ('all', 'O', 'O'), ('of', 'O', 'O'), ('metro', 'O', 'O'), ('Atlanta', 'O', 'O'), ('.', 'O', 'O')]
# 24
# 24
# 24
# TEST 24 [('@FirstLadyEve', 'O', 'O'), ('have', 'O', 'O'), ('a', 'O', 'O'), ('dating', 'O', 'O'), ('show', 'O', 'O'), ('with', 'O', 'O'), ('@ogochocinco', 'O', 'O'), ('evry', 'O', 'O'), ('week', 'O', 'O'), ("'ll", 'O', 'O'), ('compete', 'O', 'O'), ('with', 'O', 'O'), ('sum', 'O', 'O'), ('hawt', 'O', 'O'), ('dude', 'O', 'O'), ('2', 'O', 'O'), ('keep', 'O', 'O'), ('ur', 'O', 'O'), ('intrest', 'O', 'O'), ('like', 'O', 'O'), ('@willdemps', 'O', 'O'), ('my$', 'O', 'O'), ('on', 'O', 'O'), ('will', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('They', 'O', 'O'), ('have', 'O', 'O'), ('unbeatable', 'O', 'O'), ('price', 'O', 'O'), ('in', 'O', 'O'), ('town', 'O', 'O'), ('and', 'O', 'O'), ('deliver', 'O', 'O'), ('on', 'O', 'O'), ('time', 'O', 'O'), ('.', 'O', 'O')]
# 17
# 17
# 17
# TEST 17 [('I', 'O', 'O'), ('was', 'O', 'O'), ('so', 'O', 'O'), ('impressed', 'O', 'O'), ('with', 'O', 'O'), ('the', 'O', 'O'), ('honesty', 'O', 'O'), ('and', 'O', 'O'), ('integrity', 'O', 'O'), ('of', 'O', 'O'), ('Mike', 'O', 'O'), ('and', 'O', 'O'), ('everyone', 'O', 'O'), ('at', 'O', 'O'), ('Eagle', 'O', 'O'), ('Transmission', 'O', 'O'), ('!', 'O', 'O')]
# 11
# 11
# 11
# TEST 11 [('Blooming', 'O', 'O'), ('onion', 'O', 'O'), (',', 'O', 'O'), ('the', 'O', 'O'), ('only', 'O', 'O'), ('reason', 'O', 'O'), ('to', 'O', 'O'), ('visit', 'O', 'O'), ('this', 'O', 'O'), ('restaurant', 'O', 'O'), ('.', 'O', 'O')]
# 2
# 2
# 2
# TEST 2 [('Wrong', 'O', 'O'), ('Information', 'O', 'O')]
# 6
# 6
# 6
# TEST 6 [('So', 'O', 'O'), ('I', 'O', 'O'), ('ordered', 'O', 'O'), ('a', 'O', 'O'), ('slice', 'O', 'O'), ('.', 'O', 'O')]
# 7
# 7
# 7
# TEST 7 [('The', 'O', 'O'), ('New', 'O', 'O'), ('Italian', 'O', 'O'), ('Kid', 'O', 'O'), ('on', 'O', 'O'), ('the', 'O', 'O'), ('Block', 'O', 'O')]
# 27
# 27
# 27
# TEST 27 [('I', 'O', 'O'), ('am', 'O', 'O'), ('so', 'O', 'O'), ('glad', 'O', 'O'), ('that', 'O', 'O'), ('I', 'O', 'O'), ('called', 'O', 'O'), ('in', 'O', 'O'), ('to', 'O', 'O'), ('see', 'O', 'O'), ('Ana', 'O', 'O'), (',', 'O', 'O'), ('she', 'O', 'O'), ('is', 'O', 'O'), ('a', 'O', 'O'), ('lovely', 'O', 'O'), ('girl', 'O', 'O'), ('who', 'O', 'O'), ('showed', 'O', 'O'), ('nothing', 'O', 'O'), ('but', 'O', 'O'), ('care', 'O', 'O'), ('and', 'O', 'O'), ('compassion', 'O', 'O'), ('towards', 'O', 'O'), ('me', 'O', 'O'), ('.', 'O', 'O')]
# 13
# 13
# 13
# TEST 13 [('They', 'O', 'O'), ('did', 'O', 'O'), ('a', 'O', 'O'), ('vehicle', 'O', 'O'), ('wrap', 'O', 'O'), ('for', 'O', 'O'), ('my', 'O', 'O'), ('Toyota', 'O', 'O'), ('Venza', 'O', 'O'), ('that', 'O', 'O'), ('looks', 'O', 'O'), ('amazing', 'O', 'O'), ('.', 'O', 'O')]
# 3
# 3
# 3
# TEST 3 [('Excellent', 'O', 'O'), ('Pizza', 'O', 'O'), ('!!', 'O', 'O')]
# 4
# 4
# 4
# TEST 4 [('What', 'O', 'O'), ('a', 'O', 'O'), ('Dump', 'O', 'O'), ('!', 'O', 'O')]
#    P   |   R   |   F   |   EP  |   ER  |   EF  |  Acc  |   O   | non-O | ingap | B vs I
# mwestats = {'nFullTagCorrect': 16992, 'Gold_#Groups': 0, 'Gold_#GappyGroups': 0, 'Pred_#Groups': 0, 'Pred_#GappyGroups': 0, 'correct': 22135, 'gold_Oo': 22135, 'gold_pred_Oo': 22135, 'PNumer': 0, 'PDenom': 0, 'CrossGapPNumer': 0, 'CrossGapPDenom': 0, 'RNumer': 0, 'RDenom': 0, 'CrossGapRNumer': 0, 'CrossGapRDenom': 0, 'ENumer': 0, 'EPDenom': 0, 'ERDenom': 0, 'Acc': 22135/22135=1.0000, 'Tag_R_Oo': 22135/22135=1.0000, 'Tag_R_non-Oo': 0/0=nan, 'Tag_Acc_non-Oo_in-gap': 0/0=nan, 'Tag_Acc_non-Oo_B-v-I': 0/0=nan, 'Tag_Acc_I_strength': 0/0=nan, 'P': 0/0=nan, 'R': 0/0=nan, 'F': nan, 'CrossGapP': nan, 'CrossGapR': nan, 'EP': 0/0=nan, 'ER': 0/0=nan, 'EF': nan, 'Pred_#Types': 0};
#
# sststats = {'Exact Tag': Counter({'nGold': 22135, 'tp': 16992, 'Acc': 16992/22135=0.7677}), None: Counter({'nGold': 6789, 'nPred': 3615, 'tp': 2022, 'P': 2022/3615=0.5593, 'R': 2022/6789=0.2978, 'F': 1405.14/3615=0.3887}), 'v': Counter({'nGold': 2986, 'nPred': 1791, 'tp': 1035, 'P': 1035/1791=0.5779, 'R': 1035/2986=0.3466, 'F': 776.09/1791=0.4333}), 'n': Counter({'nGold': 3803, 'nPred': 1824, 'tp': 987, 'P': 987/1824=0.5411, 'R': 987/3803=0.2595, 'F': 639.87/1824=0.3508})};
#
# conf = {('v.cognition', 'v.cognition'): 145, ('v.change', None): 89, ('n.communication', 'n.group'): 13, ('v.communication', None): 133, ('n.food', 'n.food'): 119, ('v.cognition', None): 186, ('v.cognition', 'v.motion'): 7, ('n.person', 'n.person'): 146, ('v.communication', 'v.communication'): 199, ('v.motion', None): 104, ('n.communication', None): 165, ('n.person', None): 402, ('n.quantity', None): 32, ('n.location', None): 181, ('v.motion', 'v.motion'): 83, ('n.act', None): 143, ('v.stative', 'v.stative'): 548, ('n.artifact', None): 185, ('v.motion', 'v.social'): 20, ('v.stative', 'v.communication'): 20, ('n.time', 'n.time'): 182, ('n.artifact', 'n.artifact'): 138, ('v.stative', None): 390, ('n.time', None): 200, ('v.social', None): 173, ('n.food', None): 101, ('n.possession', None): 56, (None, 'n.group'): 42, (None, 'n.act'): 17, ('v.emotion', 'v.cognition'): 18, ('v.possession', None): 70, ('n.act', 'n.act'): 85, ('n.act', 'n.possession'): 5, ('v.social', 'v.cognition'): 9, ('n.group', None): 289, ('n.act', 'n.artifact'): 13, ('v.social', 'v.stative'): 34, (None, 'v.stative'): 123, ('n.event', 'n.time'): 26, ('n.group', 'n.group'): 167, ('v.social', 'v.social'): 60, ('n.possession', 'n.act'): 9, (None, 'n.artifact'): 31, ('v.perception', None): 41, ('n.location', 'n.location'): 50, ('n.communication', 'n.artifact'): 33, ('v.emotion', None): 81, ('n.attribute', 'n.cognition'): 12, (None, 'n.person'): 17, ('n.location', 'n.artifact'): 20, ('n.cognition', None): 139, ('n.animal', None): 29, ('v.contact', None): 29, ('n.person', 'n.artifact'): 8, ('v.possession', 'v.stative'): 30, ('v.social', 'v.communication'): 48, ('n.event', None): 78, ('v.possession', 'v.communication'): 24, ('v.perception', 'v.communication'): 14, ('n.attribute', None): 59, ('n.state', None): 24, ('n.event', 'n.group'): 6, ('n.attribute', 'n.group'): 3, ('n.act', 'n.food'): 5, ('n.possession', 'n.possession'): 39, ('n.event', 'n.artifact'): 5, ('n.group', 'n.artifact'): 10, ('v.competition', 'v.cognition'): 1, ('n.quantity', 'n.artifact'): 4, ('v.consumption', 'v.social'): 6, ('v.creation', None): 29, ('n.communication', 'n.act'): 9, (None, 'n.food'): 18, ('n.artifact', 'n.group'): 29, ('v.body', None): 26, ('n.artifact', 'n.act'): 7, ('n.natural_object', None): 15, ('n.body', 'n.person'): 2, ('n.state', 'n.cognition'): 6, ('v.motion', 'v.communication'): 35, ('v.change', 'v.social'): 12, ('v.cognition', 'v.communication'): 30, ('v.stative', 'v.social'): 18, ('n.event', 'n.event'): 19, ('v.change', 'v.communication'): 15, ('n.body', 'n.artifact'): 8, ('n.phenomenon', 'n.time'): 1, ('v.motion', 'v.stative'): 10, (None, 'v.communication'): 25, ('n.communication', 'n.cognition'): 8, ('v.perception', 'v.cognition'): 14, (None, 'v.motion'): 8, ('v.consumption', 'v.communication'): 4, ('n.location', 'n.group'): 23, ('v.social', 'v.motion'): 13, ('n.event', 'n.cognition'): 7, ('v.possession', 'v.social'): 21, ('v.consumption', None): 13, (None, 'n.cognition'): 20, ('v.cognition', 'v.stative'): 16, ('n.group', 'n.person'): 20, ('v.change', 'v.stative'): 13, ('v.contact', 'v.communication'): 5, ('n.time', 'n.artifact'): 1, ('v.communication', 'v.social'): 10, ('n.person', 'n.act'): 4, ('v.creation', 'v.communication'): 5, (None, 'n.location'): 7, ('n.cognition', 'n.cognition'): 38, ('n.cognition', 'n.location'): 2, ('v.communication', 'v.cognition'): 11, ('v.body', 'v.social'): 5, ('n.attribute', 'n.possession'): 1, ('n.possession', 'n.cognition'): 13, ('n.artifact', 'n.time'): 1, ('v.possession', 'v.cognition'): 2, ('n.cognition', 'n.act'): 7, ('v.body', 'v.communication'): 8, (None, 'n.possession'): 4, ('n.time', 'n.food'): 1, (None, 'n.time'): 31, ('n.person', 'n.time'): 2, ('v.contact', 'v.social'): 3, ('v.cognition', 'v.social'): 15, ('n.relation', None): 16, ('n.event', 'n.person'): 7, ('n.attribute', 'n.location'): 1, ('n.cognition', 'n.artifact'): 17, ('n.other', None): 4, ('n.substance', 'n.artifact'): 4, ('v.communication', 'v.stative'): 5, ('n.event', ...
#
#  nan%  nan%  nan%  nan%  nan%  nan%  100.00%  100.00%  nan%  nan%  nan%
#       0       0               0       0           22135   22135       0       0       0
#       0       0               0       0           22135   22135       0       0       0
#
#            GOLD       ---- PERS GROU TIME ARTI ACT LOCA COMM FOOD COGN EVEN POSS ATTR QUAN ANIM BODY STAT RELA NATU PHEN FEEL SUBS MOTI PROC OTHE SHAP PLAN stat <-- PRED
#            ----              17   42   31   31   17    7    1   18   20   10    4                                                                             123
#        n.person   584  402  146   19    2    8    4    1         1                                                                                              1
#         n.group   507  289   20  167    2   10    5    4         5    1    1    3
#          n.time   401  200    2    6  182    1    1    2         1    1    5
#      n.artifact   379  185    5   29    1  138    7              6    6    2
#           n.act   283  143    9   11    6   13   85    1         5    4    1    5
#      n.location   281  181    1   23    1   20    1   50         2         2
# n.communication   251  165    3   13    2   33    9         2    7    8    8    1
#          n.food   241  101         9         8    3            119    1
#     n.cognition   227  139    4   14    1   17    7    2             38    3    2
#         n.event   157   78    7    6   26    5    3              6    7   19
#    n.possession   124   56         3         3    9                  13    1   39
#     n.attribute    99   59    2    3        10    6    1         4   12    1    1
#      n.quantity    45   32         1    1    4         1              3    3
#        n.animal    40   29    1         1    6                   3
#          n.body    40   21    2              8                             7                        2
#         n.state    34   24              3                             6    1
#      n.relation    25   16    1    2    1         1                   4
# n.natural_object    20   15                   4                   1
#    n.phenomenon    14   10              1    1                        2
#       n.feeling    13    8    2    1                                  2
#     n.substance    12    6    1              4                   1
#        n.motive     9    7                                            2
#       n.process     9    6                                       1    1    1
#         n.other     5    4                                                 1
#         n.shape     2    1                                       1
#         n.plant     1    1
#
#            GOLD       ---- stat cogn comm soci moti poss chan emot perc body crea cont cons comp PERS POSS <-- PRED
#            ----             123    9   25   13    8                                                17    4
#       v.stative   986  390  548    5   20   18    5
#     v.cognition   399  186   16  145   30   15    7
# v.communication   361  133    5   11  199   10    3
#        v.social   337  173   34    9   48   60   13
#        v.motion   252  104   10        35   20   83
#    v.possession   150   70   30    2   24   21    3
#        v.change   137   89   13    1   15   12    5                                                 1    1
#       v.emotion   109   81    7   18    1    1    1
#    v.perception    82   41   11   14   14    2
#          v.body    43   26    3         8    5    1
#      v.creation    42   29    4    2    5    2
#       v.contact    39   29    1         5    3    1
#   v.consumption    34   13   11         4    6
#   v.competition    15    8    1    1    2    3
#
#   Acc  |   P   |   R   |   F   || R: NSST | VSST
#  76.77%  55.93%  29.78%  38.87%    25.95%  34.66%
#   16992    2022    2022               987    1035
#   22135    3615    6789              3803    2986
#
#   Acc  |   P   |   R   |   F
#  76.77%  55.93%  29.78%  38.87%
#   16992    2022    2022
#   22135    3615    6789
#
# SUMMARY SCORES
# ==============
# MWEs: P=0/0=nan R=0/0=nan F=nan%
# Supersenses: P=2022/3615=0.5593 R=2022/6789=0.2978 F=38.87%
# Combined: Acc=16992/22135=0.7677 P=2022/3615=0.5593 R=2022/6789=0.2978 F=38.87%
